# %% [markdown]
# ### Checklist for submission
#
# It is extremely important to make sure that:
#
# 1. Everything runs as expected (no bugs when running cells);
# 2. The output from each cell corresponds to its code (don't change any cell's contents without rerunning it afterwards);
# 3. All outputs are present (don't delete any of the outputs);
# 4. Fill in all the places that say `# YOUR CODE HERE`, or "**Your answer:** (fill in here)".
# 5. Never copy/paste any notebook cells. Inserting new cells is allowed, but it should not be necessary.
# 6. The notebook contains some hidden metadata which is important during our grading process. **Make sure not to corrupt any of this metadata!** The metadata may for example be corrupted if you copy/paste any notebook cells, or if you perform an unsuccessful git merge / git pull. It may also be pruned completely if using Google Colab, so watch out for this. Searching for "nbgrader" when opening the notebook in a text editor should take you to the important metadata entries.
# 7. Although we will try our very best to avoid this, it may happen that bugs are found after an assignment is released, and that we will push an updated version of the assignment to GitHub. If this happens, it is important that you update to the new version, while making sure the notebook metadata is properly updated as well. The safest way to make sure nothing gets messed up is to start from scratch on a clean updated version of the notebook, copy/pasting your code from the cells of the previous version into the cells of the new version.
# 8. If you need to have multiple parallel versions of this notebook, make sure not to move them to another directory.
# 9. Although not forced to work exclusively in the course `conda` environment, you need to make sure that the notebook will run in that environment, i.e. that you have not added any additional dependencies.
#
# Failing to meet any of these requirements might lead to the submission not being validated meaning no feedback will be provided.
#
# We advise you to perform the following steps before submission to ensure that requirements 1, 2, and 3 are always met: **Restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). This might require a bit of time, so plan ahead for this. Finally press the "Save and Checkout" button before handing in, to make sure that all your changes are saved to this .ipynb file.

# %% [markdown]
# ### Fill in name of notebook file
# This might seem silly, but the version check below needs to know the filename of the current notebook, which is not trivial to find out programmatically.
#
# You might want to have several parallel versions of the notebook, and it is fine to rename the notebook as long as it stays in the same directory. **However**, if you do rename it, you also need to update its own filename below:

# %%
nb_fname = "HA2_Group55.ipynb"

assert (nb_fname != "XXX.ipynb"), "Make sure to fill in the nb_fname variable above!"

# %% [markdown]
# ### Fill in group number and member names:

# %%
NAME1 = "Lu Qian"
NAME2 = ""
GROUP = "55"

# %% [markdown]
# ### Check Python version

# %%
from platform import python_version_tuple

assert (
    python_version_tuple()[:2] == ("3", "11")
), "You are not running Python 3.11. Make sure to run Python through the course Conda environment."

# %% [markdown]
# ### Check that notebook server has access to all required resources, and that notebook has not moved

# %%
import os

nb_dirname = os.path.abspath("")
assignment_name = os.path.basename(nb_dirname)
assert assignment_name in [
    "HA1",
    "HA2",
    "HA3",
    "HA4",
], "[ERROR] The notebook appears to have been moved from its original directory"

# %% [markdown]
# ### Verify correct nb_fname

# %%
from IPython.display import HTML, display

try:
    display(
        HTML(
            r'<script>if("{nb_fname}" != IPython.notebook.notebook_name) {{ alert("You have filled in nb_fname = \"{nb_fname}\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }}</script>'.format(
                nb_fname=nb_fname
            )
        )
    )
except NameError:
    assert False, "Make sure to fill in the nb_fname variable above!"
# Out:
# <script>if("HA2_Group55.ipynb" != IPython.notebook.notebook_name) { alert("You have filled in nb_fname = \"HA2_Group55.ipynb\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }</script>

# %% [markdown]
# ### Verify that your notebook is up-to-date and not corrupted in any way

# %%
import sys

sys.path.append("..")
from ha_utils import check_notebook_uptodate_and_not_corrupted

check_notebook_uptodate_and_not_corrupted(nb_dirname, nb_fname)
# Out:
# Matching current notebook against the following URL:
# http://raw.githubusercontent.com/dml-cth/deep-machine-learning/master/home-assignments/HA2/HA2.ipynb
# [SUCCESS] No major notebook mismatch found when comparing to latest GitHub version. (There might be minor updates, but even that is the case, submitting your work based on this notebook version would be acceptable.)

# %% [markdown]
# # HA2 - Catching Pokemon

# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://commons.wikimedia.org/wiki/Special:FilePath/Pok%C3%A9mon_GO_logo.svg" width="400">
# </div>

# %% [markdown]
# In this home assignment, you'll apply roughly the same principles we used when doing logistic regression on the Iris dataset in Computer Lab 1, but on a different and very interesting dataset. We'll use the [Predict'em All dataset from Kaggle](https://www.kaggle.com/semioniy/predictemall). To download the dataset you will need a Kaggle account. This dataset consists of roughly 293,000 [pokemon](http://www.pokemongo.com/) sightings (historical appearances of Pokemon in the Pokemon Go game), with geographical coordinates, time, weather, population density, distance to pokestops/gyms etc. as features. A comprehensive list of all the features is available at [the dataset's homepage](https://www.kaggle.com/semioniy/predictemall).
#
# The context is simple: you are a Pokemon hunter, and there are only three Pokemon left for you to complete your collection. You'll do anything to capture them, including changing where you'll spend your next holidays! You know that some Pokemon only spawn in certain places of the world. Since you like machine learning so much, you figure it would be a great idea to train a classifier that, based on a location's longitude and latitude, can tell us which Pokemon is more likely to appear there.
#
# The assignment is broken down into six steps.
#
# 1. Loading the data and extracting the desired subset of it
# 2. Visualization of the dataset
# 3. Preprocessing
# 4. Training
# 5. Evaluation
# 6. Exploration
#
# Feel free to temporarily add cells wherever you see fit, and play around with this notebook as much as you want when developing the solutions. However, the solution you upload to Canvas must have the exact format shown here, with only the cells present here.
#
# Don't restrict yourself only to what was taught so far. Some of the tasks might require you to search for new information. However, **be sure that you do the assignment using PyTorch** since we will be using it through the following assignments as well. [The Python docs](https://docs.python.org/3/), [PyTorch docs](https://pytorch.org/docs/stable/index.html), [stackoverflow](https://stackoverflow.com/), and Google are your friends!
#
# **Hint:** Solving Computer Lab 1 (CL1) is a good way to get prepared for this assignment.
#
# For your implementation to be correct your solutions should pass all tests (`assert`-statements). Further, similar to HA1, this notebook contains some questions where we ask you to reflect upon some results.

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# Import any necessary modules here.

# %%
# YOUR CODE HERE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
from matplotlib.lines import Line2D

# %% [markdown]
# ## 1. Loading and extracting subset

# %% [markdown]
# The first step consists of filtering the dataset by the three Pokémon you are interested at.
#
# Start by loading the `'300k.csv'` file using pandas. If you haven't downloaded it yet, either use [this link](https://www.kaggle.com/semioniy/predictemall) to do so (and place the file in the same folder as this notebook), or simply run the cell below. You might have to [create a new API token](https://www.kaggle.com/settings/account) before the commands work.

# %%
# !kaggle datasets download -d semioniy/predictemall
# !unzip -u predictemall.zip
# !rm -rf predictemall.zip 300k_arff 300k.arff 300k_csv
# Out:
# zsh:1: command not found: kaggle
# unzip:  cannot find or open predictemall.zip, predictemall.zip.zip or predictemall.zip.ZIP.

# %%
# TODO: load the dataset using pandas to a dataframe called df
# YOUR CODE HERE
df = pd.read_csv("./archive/300k.csv")
# Out:
# /var/folders/_q/gkvgvk_x7c37xn232bl110d40000gn/T/ipykernel_18409/519783207.py:3: DtypeWarning: Columns (0: pokestopDistanceKm) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./archive/300k.csv")

# %%
print("df shape: ", df.shape)
assert df.shape == (
    296021,
    208,
), f"Dataframe has not the right shape. {df.shape} != (296021, 208)"
assert isinstance(df, pd.DataFrame), f"df is not a dataframe. Was {type(df)}"
# Out:
# df shape:  (296021, 208)

# %% [markdown]
# Modify `df` to only have the columns `latitude`, `longitude`, and `class`.

# %%
# YOUR CODE HERE
df = df[["latitude", "longitude", "class"]]

# %%
assert len(df.columns) == 3, "There should be 3 columns"
assert len(df.shape) == 2, "The dataframe should be 2 dimensional"
assert df.shape == (296021, 3), "Wrong shape of the dataframe"
assert "latitude" in df.columns, "latitude column is missing"
assert "longitude" in df.columns, "longitude column is missing"
assert "class" in df.columns, "class column is missing"

# %% [markdown]
# Note that the `class` column specifies which pokemon it is. However, it only has the numerical id of the pokemon. For your convenience, we provide the dictionary `name_dict` to convert between ids and names (we'll do this soon).

# %%
from utils import name_dict

# %%
# example usage (you can index either by name or id)
print(name_dict["Gengar"])
print(name_dict[94])
# Out:
# 94
# Gengar

# %%
# for convenience, let's add a new column to the dataframe with the name of the pokemon
df["name"] = df["class"].apply(lambda x: name_dict[x])
print(df.head())
# Out:
#     latitude   longitude  class    name
# 0  20.525745  -97.460829     16  Pidgey
# 1  20.523695  -97.461167    133   Eevee
# 2  38.903590  -77.199780     16  Pidgey
# 3  47.665903 -122.312561     13  Weedle
# 4  47.666454 -122.311628    133   Eevee

# %% [markdown]
# We are only interested in three specific pokemon: Diglett, Seel, and Tauros.

# %% [markdown]
# <table style="width:100%">
#   <tr>
#     <th> <center>Diglett</center> </th>
#     <th> <center>Seel</center> </th>
#     <th> <center>Tauros</center> </th>
#   </tr>
#   <tr>
#     <td><img src=https://assets.pokemon.com/assets/cms2/img/pokedex/full/050_f2.png alt=Digglet></td>
#     <td><img src=https://www.pokemon.com/static-assets/content-assets/cms2/img/pokedex/full/086.png?version=2c32fbe0af2d0da707e5dbcb40472fbf></td>
#     <td><img src=https://www.pokemon.com/static-assets/content-assets/cms2/img/pokedex/full/128.png></td>
#   </tr>
# </table>

# %% [markdown]
# Filter the dataset to contain only these three types of pokemon and save it in the DataFrame `filtered_df`.

# %%
# YOUR CODE HERE
filtered_df = df[df["name"].isin(["Diglett", "Seel", "Tauros"])]

print(
    f"We have {len(filtered_df)} instances of Diglett, Seel, and Tauros in the dataset."
)
# Out:
# We have 2083 instances of Diglett, Seel, and Tauros in the dataset.

# %%
assert len(np.unique(filtered_df["class"])) == 3, "There should be 3 unique classes."
assert filtered_df.shape == (
    2083,
    4,
), "The shape of the filtered dataframe is incorrect."
assert sorted(np.unique(filtered_df["class"]).tolist()) == sorted(
    list(map(name_dict.get, ["Diglett", "Seel", "Tauros"]))
)

# %% [markdown]
#  In an earlier cell, you could see that the dataset has 208 features per pokemon sighting (`df.shape == (296021, 208)`). We will only be using the `longitude` and `latitude` features. What could be a motivation for just using these features and not all the available features?

# %% [markdown]
# **Your answer:** Using only latitude and longitude makes the task focus on the geographical distribution of Pokémon, which is the information available when choosing a travel destination. It also keeps the model simple and interpretable, reduces the risk of overfitting with a relatively small subset of data, and avoids issues caused by missing, noisy, or unavailable features. Although additional features might improve accuracy, they are not necessary for this location-based classification task.

# %% [markdown]
# ## 2. Visualization of the dataset

# %% [markdown]
# The second step consists of visualizing the dataset. This will help you understand the distribution of the features and get an idea of how hard the task will be.
#
# Plot a bar chart of the number of occurrences of each class.

# %%
# YOUR CODE HERE
class_counts = (
    filtered_df["name"]
    .value_counts()
    .reindex(["Diglett", "Seel", "Tauros"])
)

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(class_counts.index, class_counts.values)
ax.set_xlabel("Pokémon")
ax.set_ylabel("Number of occurrences")
ax.set_title("Number of sightings per Pokémon class")
plt.show()

# %% [markdown]
# Is the dataset balanced? Why/why not? Why is this important?

# %% [markdown]
# **Your answer:** The dataset is approximately balanced, but not perfectly balanced. Diglett has about 720 samples, Seel about 690, and Tauros about 670, so the class frequencies are fairly similar.
#
# This is important because a strongly imbalanced dataset can bias a classifier toward the majority class. In that case, accuracy alone may be misleading: a model could obtain high accuracy while performing poorly on minority classes. Since the three classes here have similar sizes, accuracy is a more meaningful evaluation metric.

# %% [markdown]
# Plot a scatter plot where the first dimension is longitude, the second is latitude, and each point is a Pokemon. Further, the color of each point should represent which Pokemon it is. Lastly, the marker at each point should be an `'x'`. Make sure to label each axis.
#
# Hints:
#
# - The `scatter` method from `matplotlib` accepts an argument called `c`.
# - The `scatter` method also accepts an argument called `marker`.

# %%
# YOUR CODE HERE
pokemon_colors = {
    "Diglett": "tab:blue",
    "Seel": "tab:orange",
    "Tauros": "tab:green",
}

fig, ax = plt.subplots(figsize=(9, 6))

for pokemon, color in pokemon_colors.items():
    subset = filtered_df[filtered_df["name"] == pokemon]
    ax.scatter(
        subset["longitude"],
        subset["latitude"],
        c=color,
        marker="x",
        alpha=0.7,
        label=pokemon,
    )

ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Pokémon sightings by location")
ax.legend()
plt.show()

# %% [markdown]
# Is there any other visualization you think would be useful? If so, insert them here.

# %%
# YOUR CODE HERE
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)

for ax, pokemon in zip(axes, ["Diglett", "Seel", "Tauros"]):
    subset = filtered_df[filtered_df["name"] == pokemon]

    hexbin = ax.hexbin(
        subset["longitude"],
        subset["latitude"],
        gridsize=35,
        cmap="viridis",
        mincnt=1,
    )

    ax.set_title(pokemon)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    fig.colorbar(hexbin, ax=ax, label="Number of sightings")

fig.suptitle("Spatial density of Pokémon sightings", y=1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# How hard do you think the problem is? Which classes can/cannot be easily separated?

# %% [markdown]
# **Your answer:** Tauros is likely the easiest class to identify because its sightings are concentrated in a relatively small geographical region, mainly in North America. Diglett and Seel are harder to separate because their sightings overlap in several regions, especially around Europe and parts of North America. There are also scattered outliers, so longitude and latitude alone cannot perfectly distinguish all three classes.

# %% [markdown]
# Which accuracy do you expect to achieve?

# %% [markdown]
# **Your answer:** Based on the visible overlap between Diglett and Seel, I would expect an accuracy of around 70–75%. This is clearly above the 33% random baseline for three balanced classes, but a near-perfect accuracy is unlikely when using only geographical coordinates.

# %% [markdown]
# ## 3. Preprocessing

# %% [markdown]
# The third step consists of processing the data before training, such as dividing the dataset into training, validation, and test sets. Some tranformations can also be applied to the dataset in order to improve the performance of the network. We will use some PyTorch utilities to help us with this task.
#
# Start by creating the input and output vectors, `x` and `y`. The input should be latitude and longitude, and the output should be the class of the pokemon. Note that you cannot use the class names directly, as they are strings. You need to introduce some mapping to convert them to integers (0, 1, and 2) or one-hot vectors.

# %%
# YOUR CODE HERE
x = filtered_df[["latitude", "longitude"]].to_numpy(dtype=np.float32)

# Convert Pokémon names to the class labels expected by CrossEntropyLoss.
name_to_label = {
    "Diglett": 0,
    "Seel": 1,
    "Tauros": 2,
}
y = filtered_df["name"].map(name_to_label).to_numpy(dtype=np.int64)

print(f"Shape of input data: {x.shape}")
print(f"Shape of labels: {y.shape}")
# Out:
# Shape of input data: (2083, 2)
# Shape of labels: (2083,)

# %%
assert isinstance(x, np.ndarray), "x should be a numpy array"
assert isinstance(y, np.ndarray), "y should be a numpy array"

assert x.shape[0] == y.shape[0], "x and y should have the same number of samples"
assert x.shape[-1] == 2, "x should have 2 features"
assert x.dtype == np.float32, "x should be of type float32"
if y.shape[-1] == 3:  # one-hot encoded
    assert y.max() == 1, "one-hot encoded y, at least one entry should be 1"
    assert y.min() == 0, "one-hot encoded y, at least one entry should be 0"
    assert y.sum(axis=1).all() == 1
else:  # label encoded
    assert y.max() == 2, "label encoded y, should have a max value of 2"
    assert y.min() == 0, "label encoded y, should have a min value of 0"

# %% [markdown]
# Separate your data into training (55%), validation (25%) and test sets (20%) and save them as `dataset_train`, `dataset_val`, `dataset_test`. If you wish to apply any transformation to the dataset, do it here as well.
#
# Further, create a class, PokemonDataset, inheriting from PyTorch [`Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) and use this for storing the data. In other words, `dataset_train`, `dataset_val`, `dataset_test` should have type PokemonDataset. You will need to implement a `__getitem__`, `__len__` and `__init__` method. Although perhaps a bit overkill for this assignment, it is a good practice for handling datasets in PyTorch.
#
# Last, instantiate a [`DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for each dataset, i.e., `loader_train`, `loader_val`, `loader_test`. This will fetch samples from the datasets and combine them into batches. Remember to select a suitable batch size.

# %%
# YOUR CODE HERE
class PokemonDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

indices = np.arange(len(x))

idx_train, idx_remaining = train_test_split(
    indices,
    train_size=0.55,
    random_state=42,
    stratify=y,
)

idx_val, idx_test = train_test_split(
    idx_remaining,
    test_size=20 / 45,
    random_state=42,
    stratify=y[idx_remaining],
)

dataset_train = PokemonDataset(x[idx_train], y[idx_train])
dataset_val = PokemonDataset(x[idx_val], y[idx_val])
dataset_test = PokemonDataset(x[idx_test], y[idx_test])

loader_train = DataLoader(dataset_train, batch_size=64, shuffle=True)
loader_val = DataLoader(dataset_val, batch_size=64, shuffle=False)
loader_test = DataLoader(dataset_test, batch_size=64, shuffle=False)

# %%
assert isinstance(
    dataset_train, PokemonDataset
), "dataset_train should be an instance of PokemonDataset"
assert isinstance(
    dataset_val, PokemonDataset
), "dataset_val should be an instance of PokemonDataset"
assert isinstance(
    dataset_test, PokemonDataset
), "dataset_test should be an instance of PokemonDataset"

assert (
    abs(len(dataset_train) / len(x) - 0.55) < 0.01
), "dataset_train has the wrong length, should be 55% of the data"
assert (
    abs(len(dataset_val) / len(x) - 0.25) < 0.01
), "dataset_val has the wrong length, should be 25% of the data"
assert (
    abs(len(dataset_test) / len(x) - 0.20) < 0.01
), "dataset_test has the wrong length, should be 20% of the data"

assert isinstance(
    loader_train, DataLoader
), "loader_train should be an instance of DataLoader"
assert isinstance(
    loader_val, DataLoader
), "loader_val should be an instance of DataLoader"
assert isinstance(
    loader_test, DataLoader
), "loader_test should be an instance of DataLoader"

assert len(loader_train), "loader_train should have a length"
assert len(loader_val), "loader_val should have a length"
assert len(loader_test), "loader_test should have a length"
assert isinstance(dataset_train, torch.utils.data.Dataset)
assert isinstance(dataset_val, torch.utils.data.Dataset)
assert isinstance(dataset_test, torch.utils.data.Dataset)

# %% [markdown]
# ## 4. Training

# %% [markdown]
# The fourth step is where you will choose the architecture of your network (number of hidden layers, activation functions, etc.), optimizer, loss function and then train the network.
#
# Start by implementing a training loop, and a helper function to calculate the accuracy. The training loop should calculate the loss and accuracy for both the training and validation set and print it with some regular interval (each epoch, or every few epochs, for instance). It can also be helpful to plot the loss and accuracy for both the training and validation set, either in the training loop, or after it has finished (i.e., you have to store the values during training and return them).
#
# We have prepared the `train_model` function with the arguments you need, but you have access to *args and **kwargs if you want to pass additional arguments to the function.

# %%
from typing import Callable, Union

import torch
import torch.nn as nn
import torch.utils


def accuracy(y_hat: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
    """
    Compute the accuracy of the model.

    Args:
    y_hat: torch.Tensor: The model predictions (probability per class), shape: [batch_size, num_classes]
    y: torch.Tensor: The true labels, shape: [batch_size]

    Returns:
    torch.Tensor: The accuracy of the model
    """
    # YOUR CODE HERE
    predictions = torch.argmax(y_hat, dim=1)
    acc = (predictions == y).float().mean()
    return acc


def train_model(
    model: nn.Module,
    optimizer: torch.optim,
    loss_fn: Union[Callable, nn.Module],
    num_epochs: int,
    train_dataloader: torch.utils.data.DataLoader,
    val_dataloader: torch.utils.data.DataLoader,
    device: Union[str, torch.device],
    *args,
    **kwargs,
):
    """
    Train the model.

    Args:
    model: nn.Module: The neural network model
    optimizer: torch.optim: The optimizer used to update the model parameters
    loss_fn: Union[Callable, nn.Module]: The loss function used to compute the loss
    num_epochs: int: The number of epochs to train the model
    train_dataloader: torch.utils.data.DataLoader: The training dataloader
    val_dataloader: torch.utils.data.DataLoader: The validation dataloader
    device: Union[str, torch.device]: The device to run the training on
    *args: Additional arguments to pass to the train function
    **kwargs: Additional keyword arguments to pass to the train function

    """

    # YOUR CODE HERE
    for epoch in range(num_epochs):
        model.train()
        loss = 0.0
        for x, y in train_dataloader:
            x = x.to(device)
            y = y.to(device)
            logits = model(x)
            loss = loss_fn(logits, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Validation
        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        with torch.no_grad():
            for x_val, y_val in val_dataloader:
                x_val = x_val.to(device)
                y_val = y_val.to(device)
                logits_val = model(x_val)
                loss_val = loss_fn(logits_val, y_val)
                val_loss += loss_val.item() * x_val.size(0)
                val_acc += accuracy(logits_val, y_val).item() * x_val.size(0)

        val_loss /= len(val_dataloader.dataset)
        val_acc /= len(val_dataloader.dataset)

        print(
            f"Epoch [{epoch+1}/{num_epochs}], "
            f"Train loss: {loss.item():.4f}, "
            f"Val loss: {val_loss:.4f}, "
            f"Val acc: {val_acc:.4f}"
        )

# %% [markdown]
# Next, we'll test that your training loop is correct. A [common sanity check in deep learning](https://karpathy.github.io/2019/04/25/recipe/) is to overfit to a small dataset, like a single batch of data. This ensures that shapes and devices are correctly set, and the network can learn/memorize the training data, which is a good starting point before training on the full dataset.

# %%
def test_train_loop():
    import torch.nn as nn
    import torch.optim as optim
    import torch.utils.data as data

    # init simple model, optimizer, loss_fn, dataloaders
    linear_model = nn.Linear(2, 3)
    optimizer = optim.SGD(linear_model.parameters(), lr=0.01)
    loss_fn = nn.CrossEntropyLoss()
    testing_loader_train = data.DataLoader(
        data.TensorDataset(torch.randn(2, 2), torch.randint(0, 3, (2,)))
    )
    testing_loader_val = data.DataLoader(
        data.TensorDataset(torch.randn(2, 2), torch.randint(0, 3, (2,)))
    )

    # copy parameters to check for changes
    params_before_training = list(linear_model.parameters())
    params_before_training = [p.clone().to("cpu") for p in params_before_training]

    print("Testing training loop, CPU")
    train_model(
        model=linear_model,
        optimizer=optimizer,
        loss_fn=loss_fn,
        num_epochs=100,
        train_dataloader=testing_loader_train,
        val_dataloader=testing_loader_val,
        device="cpu",
    )
    if torch.cuda.is_available():
        print("Testing training loop, CUDA")
        train_model(
            model=linear_model,
            optimizer=optimizer,
            loss_fn=loss_fn,
            num_epochs=100,
            train_dataloader=testing_loader_train,
            val_dataloader=testing_loader_val,
            device="cuda" if torch.cuda.is_available() else "cpu",
        )

    params_after_training = list(linear_model.parameters())
    params_after_training = [p.clone().to("cpu") for p in params_after_training]
    for p_before, p_after in zip(params_before_training, params_after_training):
        assert torch.any(
            p_before != p_after
        ), "Model parameters did not change during training"

    # check that we could overfit a single example
    (x, y) = next(iter(testing_loader_train))
    x.to("cpu")
    y.to("cpu")
    linear_model.to("cpu")
    assert (
        linear_model(x).argmax().item() == y.item()
    ), "Model could not overfit a single example"


def test_accuracy():
    y_pred = torch.tensor([[0.1, 0.8, 0.1], [0.3, 0.4, 0.3], [0.1, 0.1, 0.8]])
    y_true = torch.tensor([1, 0, 2])
    acc = accuracy(y_pred, y_true)
    assert isinstance(acc, torch.Tensor), "Accuracy should be a torch.Tensor"
    assert torch.isclose(acc, torch.tensor(2 / 3)), f"Accuracy is {acc}, expected 2/3"


try:
    test_train_loop()
except Exception as e:
    print(e)
    assert False, "Training test failed, see error above"

test_accuracy()
# Out:
# Testing training loop, CPU
# Epoch [1/100], Train loss: 0.6611, Val loss: 0.9316, Val acc: 0.5000
# Epoch [2/100], Train loss: 0.6627, Val loss: 0.9308, Val acc: 0.5000
# Epoch [3/100], Train loss: 0.6642, Val loss: 0.9300, Val acc: 0.5000
# Epoch [4/100], Train loss: 0.6657, Val loss: 0.9292, Val acc: 0.5000
# Epoch [5/100], Train loss: 0.6672, Val loss: 0.9284, Val acc: 0.5000
# Epoch [6/100], Train loss: 0.6687, Val loss: 0.9276, Val acc: 0.5000
# Epoch [7/100], Train loss: 0.6702, Val loss: 0.9268, Val acc: 0.5000
# Epoch [8/100], Train loss: 0.6717, Val loss: 0.9261, Val acc: 0.5000
# Epoch [9/100], Train loss: 0.6732, Val loss: 0.9253, Val acc: 0.5000
# Epoch [10/100], Train loss: 0.6746, Val loss: 0.9245, Val acc: 0.5000
# Epoch [11/100], Train loss: 0.6761, Val loss: 0.9237, Val acc: 0.5000
# Epoch [12/100], Train loss: 0.6775, Val loss: 0.9230, Val acc: 0.5000
# Epoch [13/100], Train loss: 0.6790, Val loss: 0.9222, Val acc: 0.5000
# Epoch [14/100], Train loss: 0.6804, Val loss: 0.9214, Val acc: 0.5000
# Epoch [15/100], Train loss: 0.6818, Val loss: 0.9207, Val acc: 0.5000
# Epoch [16/100], Train loss: 0.6832, Val loss: 0.9199, Val acc: 0.5000
# Epoch [17/100], Train loss: 0.6846, Val loss: 0.9191, Val acc: 0.5000
# Epoch [18/100], Train loss: 0.6860, Val loss: 0.9184, Val acc: 0.5000
# Epoch [19/100], Train loss: 0.6873, Val loss: 0.9176, Val acc: 0.5000
# Epoch [20/100], Train loss: 0.6887, Val loss: 0.9169, Val acc: 0.5000
# Epoch [21/100], Train loss: 0.6900, Val loss: 0.9161, Val acc: 0.5000
# Epoch [22/100], Train loss: 0.6914, Val loss: 0.9154, Val acc: 0.5000
# Epoch [23/100], Train loss: 0.6927, Val loss: 0.9146, Val acc: 0.5000
# Epoch [24/100], Train loss: 0.6940, Val loss: 0.9139, Val acc: 0.5000
# Epoch [25/100], Train loss: 0.6952, Val loss: 0.9131, Val acc: 0.5000
# Epoch [26/100], Train loss: 0.6965, Val loss: 0.9124, Val acc: 0.5000
# Epoch [27/100], Train loss: 0.6978, Val loss: 0.9116, Val acc: 0.5000
# Epoch [28/100], Train loss: 0.6990, Val loss: 0.9109, Val acc: 0.5000
# Epoch [29/100], Train loss: 0.7002, Val loss: 0.9101, Val acc: 0.5000
# Epoch [30/100], Train loss: 0.7015, Val loss: 0.9094, Val acc: 0.5000
# Epoch [31/100], Train loss: 0.7027, Val loss: 0.9086, Val acc: 0.5000
# Epoch [32/100], Train loss: 0.7038, Val loss: 0.9079, Val acc: 0.5000
# Epoch [33/100], Train loss: 0.7050, Val loss: 0.9071, Val acc: 0.5000
# Epoch [34/100], Train loss: 0.7062, Val loss: 0.9064, Val acc: 0.5000
# Epoch [35/100], Train loss: 0.7073, Val loss: 0.9056, Val acc: 0.5000
# Epoch [36/100], Train loss: 0.7084, Val loss: 0.9049, Val acc: 0.5000
# Epoch [37/100], Train loss: 0.7096, Val loss: 0.9041, Val acc: 0.5000
# Epoch [38/100], Train loss: 0.7106, Val loss: 0.9034, Val acc: 0.5000
# Epoch [39/100], Train loss: 0.7117, Val loss: 0.9026, Val acc: 0.5000
# Epoch [40/100], Train loss: 0.7128, Val loss: 0.9019, Val acc: 0.5000
# Epoch [41/100], Train loss: 0.7138, Val loss: 0.9011, Val acc: 0.5000
# Epoch [42/100], Train loss: 0.7149, Val loss: 0.9004, Val acc: 0.5000
# Epoch [43/100], Train loss: 0.7159, Val loss: 0.8996, Val acc: 0.5000
# Epoch [44/100], Train loss: 0.7169, Val loss: 0.8988, Val acc: 0.5000
# Epoch [45/100], Train loss: 0.7179, Val loss: 0.8981, Val acc: 0.5000
# Epoch [46/100], Train loss: 0.7189, Val loss: 0.8973, Val acc: 0.5000
# Epoch [47/100], Train loss: 0.7198, Val loss: 0.8966, Val acc: 0.5000
# Epoch [48/100], Train loss: 0.7208, Val loss: 0.8958, Val acc: 0.5000
# Epoch [49/100], Train loss: 0.7217, Val loss: 0.8950, Val acc: 0.5000
# Epoch [50/100], Train loss: 0.7226, Val loss: 0.8943, Val acc: 0.5000
# Epoch [51/100], Train loss: 0.7235, Val loss: 0.8935, Val acc: 0.5000
# Epoch [52/100], Train loss: 0.7244, Val loss: 0.8928, Val acc: 0.5000
# Epoch [53/100], Train loss: 0.7253, Val loss: 0.8920, Val acc: 0.5000
# Epoch [54/100], Train loss: 0.7261, Val loss: 0.8912, Val acc: 0.5000
# Epoch [55/100], Train loss: 0.7270, Val loss: 0.8905, Val acc: 0.5000
# Epoch [56/100], Train loss: 0.7278, Val loss: 0.8897, Val acc: 0.5000
# Epoch [57/100], Train loss: 0.7286, Val loss: 0.8889, Val acc: 0.5000
# Epoch [58/100], Train loss: 0.7294, Val loss: 0.8881, Val acc: 0.5000
# Epoch [59/100], Train loss: 0.7302, Val loss: 0.8874, Val acc: 0.5000
# Epoch [60/100], Train loss: 0.7309, Val loss: 0.8866, Val acc: 0.5000
# Epoch [61/100], Train loss: 0.7317, Val loss: 0.8858, Val acc: 0.5000
# Epoch [62/100], Train loss: 0.7324, Val loss: 0.8850, Val acc: 0.5000
# Epoch [63/100], Train loss: 0.7331, Val loss: 0.8843, Val acc: 0.5000
# Epoch [64/100], Train loss: 0.7338, Val loss: 0.8835, Val acc: 0.5000
# Epoch [65/100], Train loss: 0.7345, Val loss: 0.8827, Val acc: 0.5000
# Epoch [66/100], Train loss: 0.7352, Val loss: 0.8819, Val acc: 0.5000
# Epoch [67/100], Train loss: 0.7359, Val loss: 0.8811, Val acc: 0.5000
# Epoch [68/100], Train loss: 0.7365, Val loss: 0.8803, Val acc: 0.5000
# Epoch [69/100], Train loss: 0.7371, Val loss: 0.8795, Val acc: 0.5000
# Epoch [70/100], Train loss: 0.7377, Val loss: 0.8787, Val acc: 0.5000
# Epoch [71/100], Train loss: 0.7383, Val loss: 0.8780, Val acc: 0.5000
# Epoch [72/100], Train loss: 0.7389, Val loss: 0.8772, Val acc: 0.5000
# Epoch [73/100], Train loss: 0.7395, Val loss: 0.8764, Val acc: 0.5000
# Epoch [74/100], Train loss: 0.7401, Val loss: 0.8756, Val acc: 0.5000
# Epoch [75/100], Train loss: 0.7406, Val loss: 0.8748, Val acc: 0.5000
# Epoch [76/100], Train loss: 0.7412, Val loss: 0.8740, Val acc: 0.5000
# Epoch [77/100], Train loss: 0.7417, Val loss: 0.8732, Val acc: 0.5000
# Epoch [78/100], Train loss: 0.7422, Val loss: 0.8724, Val acc: 0.5000
# Epoch [79/100], Train loss: 0.7427, Val loss: 0.8715, Val acc: 0.5000
# Epoch [80/100], Train loss: 0.7431, Val loss: 0.8707, Val acc: 0.5000
# Epoch [81/100], Train loss: 0.7436, Val loss: 0.8699, Val acc: 0.5000
# Epoch [82/100], Train loss: 0.7441, Val loss: 0.8691, Val acc: 0.5000
# Epoch [83/100], Train loss: 0.7445, Val loss: 0.8683, Val acc: 0.5000
# Epoch [84/100], Train loss: 0.7449, Val loss: 0.8675, Val acc: 0.5000
# Epoch [85/100], Train loss: 0.7453, Val loss: 0.8667, Val acc: 0.5000
# Epoch [86/100], Train loss: 0.7457, Val loss: 0.8659, Val acc: 0.5000
# Epoch [87/100], Train loss: 0.7461, Val loss: 0.8650, Val acc: 0.5000
# Epoch [88/100], Train loss: 0.7465, Val loss: 0.8642, Val acc: 0.5000
# Epoch [89/100], Train loss: 0.7469, Val loss: 0.8634, Val acc: 0.5000
# Epoch [90/100], Train loss: 0.7472, Val loss: 0.8626, Val acc: 0.5000
# Epoch [91/100], Train loss: 0.7476, Val loss: 0.8617, Val acc: 0.5000
# Epoch [92/100], Train loss: 0.7479, Val loss: 0.8609, Val acc: 0.5000
# Epoch [93/100], Train loss: 0.7482, Val loss: 0.8601, Val acc: 0.5000
# Epoch [94/100], Train loss: 0.7485, Val loss: 0.8593, Val acc: 0.5000
# Epoch [95/100], Train loss: 0.7488, Val loss: 0.8584, Val acc: 0.5000
# Epoch [96/100], Train loss: 0.7491, Val loss: 0.8576, Val acc: 0.5000
# Epoch [97/100], Train loss: 0.7494, Val loss: 0.8568, Val acc: 0.5000
# Epoch [98/100], Train loss: 0.7496, Val loss: 0.8559, Val acc: 0.5000
# Epoch [99/100], Train loss: 0.7499, Val loss: 0.8551, Val acc: 0.5000
# Epoch [100/100], Train loss: 0.7501, Val loss: 0.8543, Val acc: 0.5000

# %% [markdown]
# Now, create a neural network using PyTorch. You can use any architecture you want. Save the model in the variable `model`.

# %%
# YOUR CODE HERE
class PokemonClassifier(nn.Module):
    def __init__(self):
        super().__init__()

        self.network = nn.Sequential(
            nn.Linear(2, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 3),
        )

    def forward(self, x):
        return self.network(x)


model = PokemonClassifier()

# %%
assert isinstance(model, nn.Module)


# check that we can run input of shape (batch_size, 2) through the model, with batch_size=16
def test_model_output_shape(model):
    is_model_on_cuda = next(model.parameters()).is_cuda
    device = torch.device("cuda" if is_model_on_cuda else "cpu")
    assert (
        len(model(torch.randn(16, 2, device=device))) == 16
    ), "The model should not change the batch size"


test_model_output_shape(model)

# %% [markdown]
# Train the network.
#
# For you to pass this assignment, you must obtain an accuracy on the test set greater than 60%. You can use the validation set as a proxy during development, but remember that they can differ slightly. We use the test set, as this better represents the performance of the model on new, unseen data (which is the ultimate goal).
#
# To reach the level of performance, it may be necessary to search for a good architecture by trying several different ones. Last, if you want a challenge, try getting an accuracy greater than 75% (our reference solution achieves ~78%).
#
# Again, it might be useful to plot the loss and accuracy (for training and validation) during training.

# %%
# YOUR CODE HERE
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

num_epochs = 200

train_model(
    model=model,
    optimizer=optimizer,
    loss_fn=loss_fn,
    num_epochs=num_epochs,
    train_dataloader=loader_train,
    val_dataloader=loader_val,
    device=device,
)
# Out:
# Epoch [1/200], Train loss: 0.7691, Val loss: 0.7746, Val acc: 0.6392
# Epoch [2/200], Train loss: 0.8062, Val loss: 0.7817, Val acc: 0.6411
# Epoch [3/200], Train loss: 0.8517, Val loss: 0.7690, Val acc: 0.6449
# Epoch [4/200], Train loss: 0.7437, Val loss: 0.7823, Val acc: 0.6507
# Epoch [5/200], Train loss: 0.8941, Val loss: 0.7877, Val acc: 0.6564
# Epoch [6/200], Train loss: 0.7717, Val loss: 0.7688, Val acc: 0.6430
# Epoch [7/200], Train loss: 0.7720, Val loss: 0.7755, Val acc: 0.6468
# Epoch [8/200], Train loss: 0.7217, Val loss: 0.7715, Val acc: 0.6392
# Epoch [9/200], Train loss: 0.8103, Val loss: 0.7945, Val acc: 0.6545
# Epoch [10/200], Train loss: 0.7334, Val loss: 0.7729, Val acc: 0.6699
# Epoch [11/200], Train loss: 0.7116, Val loss: 0.7824, Val acc: 0.6641
# Epoch [12/200], Train loss: 0.6495, Val loss: 0.7759, Val acc: 0.6449
# Epoch [13/200], Train loss: 0.6923, Val loss: 0.7735, Val acc: 0.6449
# Epoch [14/200], Train loss: 0.7640, Val loss: 0.7954, Val acc: 0.6392
# Epoch [15/200], Train loss: 0.6319, Val loss: 0.7762, Val acc: 0.6699
# Epoch [16/200], Train loss: 0.6949, Val loss: 0.7775, Val acc: 0.6449
# Epoch [17/200], Train loss: 0.7939, Val loss: 0.7688, Val acc: 0.6449
# Epoch [18/200], Train loss: 0.7831, Val loss: 0.7792, Val acc: 0.6372
# Epoch [19/200], Train loss: 0.7427, Val loss: 0.7705, Val acc: 0.6468
# Epoch [20/200], Train loss: 0.6483, Val loss: 0.7750, Val acc: 0.6449
# Epoch [21/200], Train loss: 0.9055, Val loss: 0.7955, Val acc: 0.6545
# Epoch [22/200], Train loss: 0.8320, Val loss: 0.7771, Val acc: 0.6679
# Epoch [23/200], Train loss: 0.7127, Val loss: 0.7724, Val acc: 0.6564
# Epoch [24/200], Train loss: 0.8304, Val loss: 0.7846, Val acc: 0.6660
# Epoch [25/200], Train loss: 0.8456, Val loss: 0.7769, Val acc: 0.6449
# Epoch [26/200], Train loss: 0.7942, Val loss: 0.7709, Val acc: 0.6468
# Epoch [27/200], Train loss: 0.9010, Val loss: 0.7704, Val acc: 0.6468
# Epoch [28/200], Train loss: 0.7395, Val loss: 0.7702, Val acc: 0.6353
# Epoch [29/200], Train loss: 0.7668, Val loss: 0.7857, Val acc: 0.6679
# Epoch [30/200], Train loss: 0.7799, Val loss: 0.7687, Val acc: 0.6468
# Epoch [31/200], Train loss: 0.8066, Val loss: 0.7706, Val acc: 0.6468
# Epoch [32/200], Train loss: 0.8033, Val loss: 0.7712, Val acc: 0.6315
# Epoch [33/200], Train loss: 0.6106, Val loss: 0.7657, Val acc: 0.6468
# Epoch [34/200], Train loss: 0.8128, Val loss: 0.7760, Val acc: 0.6449
# Epoch [35/200], Train loss: 0.7375, Val loss: 0.7861, Val acc: 0.6353
# Epoch [36/200], Train loss: 0.5836, Val loss: 0.7685, Val acc: 0.6526
# Epoch [37/200], Train loss: 0.8380, Val loss: 0.7730, Val acc: 0.6449
# Epoch [38/200], Train loss: 0.7086, Val loss: 0.7679, Val acc: 0.6449
# Epoch [39/200], Train loss: 0.7553, Val loss: 0.7732, Val acc: 0.6468
# Epoch [40/200], Train loss: 0.7866, Val loss: 0.7749, Val acc: 0.6526
# Epoch [41/200], Train loss: 0.7805, Val loss: 0.7705, Val acc: 0.6526
# Epoch [42/200], Train loss: 0.5597, Val loss: 0.7844, Val acc: 0.6699
# Epoch [43/200], Train loss: 0.8797, Val loss: 0.8018, Val acc: 0.6526
# Epoch [44/200], Train loss: 0.8400, Val loss: 0.7772, Val acc: 0.6526
# Epoch [45/200], Train loss: 0.7995, Val loss: 0.7789, Val acc: 0.6699
# Epoch [46/200], Train loss: 0.7822, Val loss: 0.7703, Val acc: 0.6468
# Epoch [47/200], Train loss: 0.6800, Val loss: 0.7727, Val acc: 0.6449
# Epoch [48/200], Train loss: 0.7805, Val loss: 0.7719, Val acc: 0.6449
# Epoch [49/200], Train loss: 0.7893, Val loss: 0.7685, Val acc: 0.6545
# Epoch [50/200], Train loss: 0.7936, Val loss: 0.7669, Val acc: 0.6468
# Epoch [51/200], Train loss: 0.7576, Val loss: 0.7740, Val acc: 0.6526
# Epoch [52/200], Train loss: 0.7771, Val loss: 0.7739, Val acc: 0.6526
# Epoch [53/200], Train loss: 0.8476, Val loss: 0.7767, Val acc: 0.6545
# Epoch [54/200], Train loss: 0.7963, Val loss: 0.7802, Val acc: 0.6315
# Epoch [55/200], Train loss: 0.8635, Val loss: 0.7792, Val acc: 0.6699
# Epoch [56/200], Train loss: 0.6056, Val loss: 0.7719, Val acc: 0.6449
# Epoch [57/200], Train loss: 0.6779, Val loss: 0.7663, Val acc: 0.6468
# Epoch [58/200], Train loss: 0.8000, Val loss: 0.7773, Val acc: 0.6468
# Epoch [59/200], Train loss: 0.7173, Val loss: 0.7711, Val acc: 0.6468
# Epoch [60/200], Train loss: 0.6512, Val loss: 0.7700, Val acc: 0.6392
# Epoch [61/200], Train loss: 0.7309, Val loss: 0.7832, Val acc: 0.6526
# Epoch [62/200], Train loss: 0.7126, Val loss: 0.8046, Val acc: 0.6641
# Epoch [63/200], Train loss: 0.7312, Val loss: 0.7683, Val acc: 0.6372
# Epoch [64/200], Train loss: 0.7268, Val loss: 0.7664, Val acc: 0.6526
# Epoch [65/200], Train loss: 0.7522, Val loss: 0.7732, Val acc: 0.6468
# Epoch [66/200], Train loss: 0.6384, Val loss: 0.7654, Val acc: 0.6468
# Epoch [67/200], Train loss: 0.9154, Val loss: 0.8995, Val acc: 0.5854
# Epoch [68/200], Train loss: 0.8249, Val loss: 0.7779, Val acc: 0.6545
# Epoch [69/200], Train loss: 0.7258, Val loss: 0.7709, Val acc: 0.6526
# Epoch [70/200], Train loss: 0.6664, Val loss: 0.7688, Val acc: 0.6468
# Epoch [71/200], Train loss: 0.8415, Val loss: 0.7791, Val acc: 0.6564
# Epoch [72/200], Train loss: 0.6880, Val loss: 0.7671, Val acc: 0.6468
# Epoch [73/200], Train loss: 0.7252, Val loss: 0.7689, Val acc: 0.6526
# Epoch [74/200], Train loss: 0.8010, Val loss: 0.7697, Val acc: 0.6411
# Epoch [75/200], Train loss: 0.7102, Val loss: 0.7643, Val acc: 0.6526
# Epoch [76/200], Train loss: 0.7832, Val loss: 0.7801, Val acc: 0.6353
# Epoch [77/200], Train loss: 0.7807, Val loss: 0.7684, Val acc: 0.6238
# Epoch [78/200], Train loss: 0.7558, Val loss: 0.7679, Val acc: 0.6238
# Epoch [79/200], Train loss: 0.7723, Val loss: 0.7705, Val acc: 0.6449
# Epoch [80/200], Train loss: 0.7947, Val loss: 0.7646, Val acc: 0.6526
# Epoch [81/200], Train loss: 0.5862, Val loss: 0.7750, Val acc: 0.6468
# Epoch [82/200], Train loss: 0.9128, Val loss: 0.7650, Val acc: 0.6238
# Epoch [83/200], Train loss: 0.7720, Val loss: 0.7652, Val acc: 0.6526
# Epoch [84/200], Train loss: 0.7863, Val loss: 0.7652, Val acc: 0.6353
# Epoch [85/200], Train loss: 0.7914, Val loss: 0.7639, Val acc: 0.6526
# Epoch [86/200], Train loss: 0.7346, Val loss: 0.7676, Val acc: 0.6449
# Epoch [87/200], Train loss: 0.8150, Val loss: 0.7643, Val acc: 0.6526
# Epoch [88/200], Train loss: 0.8821, Val loss: 0.7699, Val acc: 0.6468
# Epoch [89/200], Train loss: 0.6748, Val loss: 0.7682, Val acc: 0.6238
# Epoch [90/200], Train loss: 0.9139, Val loss: 0.7661, Val acc: 0.6564
# Epoch [91/200], Train loss: 0.7491, Val loss: 0.7756, Val acc: 0.6641
# Epoch [92/200], Train loss: 0.7783, Val loss: 0.7635, Val acc: 0.6468
# Epoch [93/200], Train loss: 0.7204, Val loss: 0.7628, Val acc: 0.6545
# Epoch [94/200], Train loss: 0.7801, Val loss: 0.7692, Val acc: 0.6468
# Epoch [95/200], Train loss: 0.6337, Val loss: 0.7645, Val acc: 0.6545
# Epoch [96/200], Train loss: 0.8034, Val loss: 0.7823, Val acc: 0.6737
# Epoch [97/200], Train loss: 0.9267, Val loss: 0.7624, Val acc: 0.6526
# Epoch [98/200], Train loss: 0.7782, Val loss: 0.7670, Val acc: 0.6564
# Epoch [99/200], Train loss: 0.8214, Val loss: 0.7706, Val acc: 0.6526
# Epoch [100/200], Train loss: 0.6168, Val loss: 0.7630, Val acc: 0.6468
# Epoch [101/200], Train loss: 0.7916, Val loss: 0.7774, Val acc: 0.6545
# Epoch [102/200], Train loss: 0.8462, Val loss: 0.7594, Val acc: 0.6334
# Epoch [103/200], Train loss: 0.6340, Val loss: 0.7790, Val acc: 0.6334
# Epoch [104/200], Train loss: 0.7065, Val loss: 0.7613, Val acc: 0.6276
# Epoch [105/200], Train loss: 0.6335, Val loss: 0.7660, Val acc: 0.6392
# Epoch [106/200], Train loss: 0.6737, Val loss: 0.7700, Val acc: 0.6468
# Epoch [107/200], Train loss: 0.7576, Val loss: 0.7674, Val acc: 0.6641
# Epoch [108/200], Train loss: 0.7372, Val loss: 0.7825, Val acc: 0.6449
# Epoch [109/200], Train loss: 0.7762, Val loss: 0.7916, Val acc: 0.6468
# Epoch [110/200], Train loss: 0.7481, Val loss: 0.7682, Val acc: 0.6699
# Epoch [111/200], Train loss: 0.7519, Val loss: 0.7623, Val acc: 0.6545
# Epoch [112/200], Train loss: 0.7537, Val loss: 0.7699, Val acc: 0.6526
# Epoch [113/200], Train loss: 0.7324, Val loss: 0.7617, Val acc: 0.6411
# Epoch [114/200], Train loss: 0.7577, Val loss: 0.7735, Val acc: 0.6564
# Epoch [115/200], Train loss: 0.7778, Val loss: 0.7984, Val acc: 0.6353
# Epoch [116/200], Train loss: 0.6076, Val loss: 0.7657, Val acc: 0.6526
# Epoch [117/200], Train loss: 0.6187, Val loss: 0.7646, Val acc: 0.6468
# Epoch [118/200], Train loss: 0.7955, Val loss: 0.7647, Val acc: 0.6468
# Epoch [119/200], Train loss: 0.7691, Val loss: 0.7635, Val acc: 0.6545
# Epoch [120/200], Train loss: 0.7668, Val loss: 0.7618, Val acc: 0.6526
# Epoch [121/200], Train loss: 0.8070, Val loss: 0.7617, Val acc: 0.6526
# Epoch [122/200], Train loss: 0.7534, Val loss: 0.7611, Val acc: 0.6372
# Epoch [123/200], Train loss: 0.8373, Val loss: 0.7808, Val acc: 0.6276
# Epoch [124/200], Train loss: 0.7959, Val loss: 0.7660, Val acc: 0.6545
# Epoch [125/200], Train loss: 0.7666, Val loss: 0.7658, Val acc: 0.6430
# Epoch [126/200], Train loss: 0.6892, Val loss: 0.7717, Val acc: 0.6622
# Epoch [127/200], Train loss: 0.6605, Val loss: 0.7712, Val acc: 0.6372
# Epoch [128/200], Train loss: 0.6148, Val loss: 0.7641, Val acc: 0.6430
# Epoch [129/200], Train loss: 0.6712, Val loss: 0.7682, Val acc: 0.6526
# Epoch [130/200], Train loss: 0.7736, Val loss: 0.7673, Val acc: 0.6468
# Epoch [131/200], Train loss: 0.6031, Val loss: 0.7625, Val acc: 0.6449
# Epoch [132/200], Train loss: 0.8659, Val loss: 0.7637, Val acc: 0.6564
# Epoch [133/200], Train loss: 0.6357, Val loss: 0.7742, Val acc: 0.6641
# Epoch [134/200], Train loss: 0.6981, Val loss: 0.7642, Val acc: 0.6583
# Epoch [135/200], Train loss: 0.8134, Val loss: 0.7619, Val acc: 0.6526
# Epoch [136/200], Train loss: 0.7473, Val loss: 0.7707, Val acc: 0.6257
# Epoch [137/200], Train loss: 0.8691, Val loss: 0.7729, Val acc: 0.6315
# Epoch [138/200], Train loss: 0.8588, Val loss: 0.7796, Val acc: 0.6315
# Epoch [139/200], Train loss: 0.8355, Val loss: 0.8024, Val acc: 0.6296
# Epoch [140/200], Train loss: 0.6209, Val loss: 0.7636, Val acc: 0.6526
# Epoch [141/200], Train loss: 0.7835, Val loss: 0.7663, Val acc: 0.6545
# Epoch [142/200], Train loss: 0.6560, Val loss: 0.7709, Val acc: 0.6334
# Epoch [143/200], Train loss: 0.8030, Val loss: 0.7743, Val acc: 0.6814
# Epoch [144/200], Train loss: 0.7069, Val loss: 0.7710, Val acc: 0.6449
# Epoch [145/200], Train loss: 0.8176, Val loss: 0.7658, Val acc: 0.6564
# Epoch [146/200], Train loss: 0.9162, Val loss: 0.7604, Val acc: 0.6526
# Epoch [147/200], Train loss: 0.7700, Val loss: 0.7812, Val acc: 0.6526
# Epoch [148/200], Train loss: 0.7487, Val loss: 0.7663, Val acc: 0.6430
# Epoch [149/200], Train loss: 0.6680, Val loss: 0.7681, Val acc: 0.6583
# Epoch [150/200], Train loss: 0.7553, Val loss: 0.7712, Val acc: 0.6814
# Epoch [151/200], Train loss: 0.8077, Val loss: 0.7664, Val acc: 0.6545
# Epoch [152/200], Train loss: 0.7065, Val loss: 0.7588, Val acc: 0.6372
# Epoch [153/200], Train loss: 0.8180, Val loss: 0.7710, Val acc: 0.6488
# Epoch [154/200], Train loss: 0.7964, Val loss: 0.7686, Val acc: 0.6526
# Epoch [155/200], Train loss: 0.6623, Val loss: 0.7677, Val acc: 0.6737
# Epoch [156/200], Train loss: 0.6492, Val loss: 0.7663, Val acc: 0.6353
# Epoch [157/200], Train loss: 0.7747, Val loss: 0.7617, Val acc: 0.6526
# Epoch [158/200], Train loss: 0.7970, Val loss: 0.7622, Val acc: 0.6430
# Epoch [159/200], Train loss: 0.8660, Val loss: 0.7699, Val acc: 0.6583
# Epoch [160/200], Train loss: 0.6681, Val loss: 0.7751, Val acc: 0.6315
# Epoch [161/200], Train loss: 0.8274, Val loss: 0.7672, Val acc: 0.6315
# Epoch [162/200], Train loss: 0.6227, Val loss: 0.7675, Val acc: 0.6468
# Epoch [163/200], Train loss: 0.6579, Val loss: 0.7612, Val acc: 0.6660
# Epoch [164/200], Train loss: 0.7765, Val loss: 0.7664, Val acc: 0.6296
# Epoch [165/200], Train loss: 0.8109, Val loss: 0.7651, Val acc: 0.6411
# Epoch [166/200], Train loss: 0.6768, Val loss: 0.7799, Val acc: 0.6967
# Epoch [167/200], Train loss: 0.5755, Val loss: 0.7761, Val acc: 0.6315
# Epoch [168/200], Train loss: 0.8165, Val loss: 0.7854, Val acc: 0.6296
# Epoch [169/200], Train loss: 0.8909, Val loss: 0.7642, Val acc: 0.6468
# Epoch [170/200], Train loss: 0.7551, Val loss: 0.7593, Val acc: 0.6430
# Epoch [171/200], Train loss: 0.8283, Val loss: 0.7719, Val acc: 0.6583
# Epoch [172/200], Train loss: 0.7070, Val loss: 0.7689, Val acc: 0.6641
# Epoch [173/200], Train loss: 0.8769, Val loss: 0.7578, Val acc: 0.6468
# Epoch [174/200], Train loss: 0.7132, Val loss: 0.7750, Val acc: 0.6583
# Epoch [175/200], Train loss: 0.7116, Val loss: 0.7593, Val acc: 0.6488
# Epoch [176/200], Train loss: 0.8978, Val loss: 0.7670, Val acc: 0.6315
# Epoch [177/200], Train loss: 0.6799, Val loss: 0.7596, Val acc: 0.6449
# Epoch [178/200], Train loss: 0.7721, Val loss: 0.7674, Val acc: 0.6526
# Epoch [179/200], Train loss: 0.6968, Val loss: 0.7610, Val acc: 0.6468
# Epoch [180/200], Train loss: 0.7121, Val loss: 0.7734, Val acc: 0.6737
# Epoch [181/200], Train loss: 0.7092, Val loss: 0.7595, Val acc: 0.6468
# Epoch [182/200], Train loss: 0.6624, Val loss: 0.7671, Val acc: 0.6660
# Epoch [183/200], Train loss: 0.8752, Val loss: 0.7627, Val acc: 0.6545
# Epoch [184/200], Train loss: 0.7303, Val loss: 0.7625, Val acc: 0.6526
# Epoch [185/200], Train loss: 0.7088, Val loss: 0.7656, Val acc: 0.6430
# Epoch [186/200], Train loss: 0.8196, Val loss: 0.7623, Val acc: 0.6449
# Epoch [187/200], Train loss: 0.8373, Val loss: 0.7648, Val acc: 0.6392
# Epoch [188/200], Train loss: 0.7891, Val loss: 0.7689, Val acc: 0.6622
# Epoch [189/200], Train loss: 0.6837, Val loss: 0.7608, Val acc: 0.6699
# Epoch [190/200], Train loss: 0.6713, Val loss: 0.7666, Val acc: 0.6488
# Epoch [191/200], Train loss: 0.8718, Val loss: 0.7635, Val acc: 0.6430
# Epoch [192/200], Train loss: 0.6553, Val loss: 0.7643, Val acc: 0.6564
# Epoch [193/200], Train loss: 0.8110, Val loss: 0.7564, Val acc: 0.6372
# Epoch [194/200], Train loss: 0.7674, Val loss: 0.7719, Val acc: 0.6468
# Epoch [195/200], Train loss: 0.6216, Val loss: 0.7673, Val acc: 0.6372
# Epoch [196/200], Train loss: 0.7419, Val loss: 0.7608, Val acc: 0.6583
# Epoch [197/200], Train loss: 0.9984, Val loss: 0.7648, Val acc: 0.6564
# Epoch [198/200], Train loss: 0.7924, Val loss: 0.7669, Val acc: 0.6699
# Epoch [199/200], Train loss: 0.8340, Val loss: 0.7647, Val acc: 0.6526
# Epoch [200/200], Train loss: 0.7580, Val loss: 0.7594, Val acc: 0.6545

# %% [markdown]
# Let's have a look at what we have learned! Create a function that visualizes the decision regions of the network. Overlap it with the points corresponding to the training data and validations data, such as in Section 2, by using the scatter plot function. The training and validation points should have different markers and/or colors. Last, call the function to visualize the decision regions of your network.
#
# Hint: A simple way to show the decision region is to generate a lot of points within a predefined range of longitude and latitude and apply your network to it. However, feel free to explore other ways.

# %%
def plot_decision_region(model: nn.Module, x_train, y_train, x_val, y_val):
    """
    Plot the decision region of the model.

    Args:
    model: nn.Module: The trained model
    x_train: The training features, use whatever representation you prefer (e.g. numpy array, torch.Tensor, dataset, dataloader)
    y_train: The training labels, use whatever representation you prefer (e.g. numpy array, torch.Tensor, dataset, dataloader)
    x_val: The validation features, use whatever representation you prefer (e.g. numpy array, torch.Tensor, dataset, dataloader)
    y_val: The validation labels, use whatever representation you prefer (e.g. numpy array, torch.Tensor, dataset, dataloader)
    """
    # YOUR CODE HERE
    all_x = np.vstack([x_train, x_val])
    lat_min, lat_max = all_x[:, 0].min() - 2, all_x[:, 0].max() + 2
    lon_min, lon_max = all_x[:, 1].min() - 2, all_x[:, 1].max() + 2

    # Create a dense grid of possible geographic locations.
    longitude_grid, latitude_grid = np.meshgrid(
        np.linspace(lon_min, lon_max, 300),
        np.linspace(lat_min, lat_max, 250),
    )

    # Convert grid back to model input order: [latitude, longitude].
    grid_points = np.column_stack(
        [latitude_grid.ravel(), longitude_grid.ravel()]
    ).astype(np.float32)

    device = next(model.parameters()).device
    was_training = model.training
    model.eval()

    with torch.no_grad():
        grid_tensor = torch.tensor(grid_points, dtype=torch.float32, device=device)
        grid_predictions = model(grid_tensor).argmax(dim=1).cpu().numpy()

    if was_training:
        model.train()

    decision_regions = grid_predictions.reshape(latitude_grid.shape)

    fig, ax = plt.subplots(figsize=(10, 6))

    ax.contourf(
        longitude_grid,
        latitude_grid,
        decision_regions,
        levels=[-0.5, 0.5, 1.5, 2.5],
        cmap="Pastel1",
        alpha=0.45,
    )

    # Training data: circles. Validation data: x markers.
    ax.scatter(
        x_train[:, 1],
        x_train[:, 0],
        c=y_train,
        cmap="Set1",
        marker="o",
        s=22,
        alpha=0.7,
        label="Training data",
    )
    ax.scatter(
        x_val[:, 1],
        x_val[:, 0],
        c=y_val,
        cmap="Set1",
        marker="x",
        s=35,
        linewidths=1.2,
        label="Validation data",
    )

    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.set_title("Decision regions of the Pokémon classifier")

    ax.legend(
        handles=[
            Line2D([0], [0], marker="o", color="w", label="Training data",
                   markerfacecolor="gray", markersize=8),
            Line2D([0], [0], marker="x", color="gray", label="Validation data",
                   linestyle="None", markersize=8),
        ]
    )

    plt.show()

plot_decision_region(
    model,
    dataset_train.x,
    dataset_train.y,
    dataset_val.x,
    dataset_val.y,
)

# %% [markdown]
# Do the learned decision regions look like you would expect? Can they be improved? In what sense, and how would that change your model? Please comment on your results.

# %% [markdown]
# **Your answer:** The decision regions broadly match the geographic structure of the data. The model assigns separate regions to the dense sighting clusters, especially around the European cluster, while the large low-density areas are mostly assigned to one class. This is expected because longitude and latitude provide useful information about where each Pokémon is commonly observed.

# %% [markdown]
# ### 4.1. Model capacity and generalization
#
# Now we have all the neccessary tools to do a small experiment on model capacity and implications on generalization.
#
# Begin by defining a neural network `tiny_model` with a single linear layer and appropriate activation function. Then, train the network until convergence (should be fast).

# %%
# A linear classifier: one affine layer that outputs three class logits.
tiny_model = nn.Linear(2, 3).to(device)
tiny_optimizer = torch.optim.Adam(tiny_model.parameters(), lr=0.02)

train_model(
    model=tiny_model,
    optimizer=tiny_optimizer,
    loss_fn=nn.CrossEntropyLoss(),
    num_epochs=300,
    train_dataloader=loader_train,
    val_dataloader=loader_val,
    device=device,
)
# Out:
# Epoch [1/300], Train loss: 12.8022, Val loss: 11.1526, Val acc: 0.5374
# Epoch [2/300], Train loss: 4.1542, Val loss: 3.8234, Val acc: 0.5816
# Epoch [3/300], Train loss: 3.0570, Val loss: 2.6130, Val acc: 0.6679
# Epoch [4/300], Train loss: 1.9561, Val loss: 1.6158, Val acc: 0.6430
# Epoch [5/300], Train loss: 1.0487, Val loss: 0.9722, Val acc: 0.5662
# Epoch [6/300], Train loss: 0.9240, Val loss: 1.0165, Val acc: 0.5374
# Epoch [7/300], Train loss: 0.8856, Val loss: 0.9750, Val acc: 0.5374
# Epoch [8/300], Train loss: 0.9463, Val loss: 0.9358, Val acc: 0.4491
# Epoch [9/300], Train loss: 0.8069, Val loss: 1.0159, Val acc: 0.5374
# Epoch [10/300], Train loss: 1.0156, Val loss: 0.9892, Val acc: 0.4299
# Epoch [11/300], Train loss: 1.0056, Val loss: 0.9350, Val acc: 0.4971
# Epoch [12/300], Train loss: 1.1709, Val loss: 1.0577, Val acc: 0.4952
# Epoch [13/300], Train loss: 1.1930, Val loss: 0.9737, Val acc: 0.5374
# Epoch [14/300], Train loss: 0.9206, Val loss: 0.9267, Val acc: 0.4530
# Epoch [15/300], Train loss: 0.9788, Val loss: 0.9511, Val acc: 0.5374
# Epoch [16/300], Train loss: 0.9281, Val loss: 0.9246, Val acc: 0.5451
# Epoch [17/300], Train loss: 0.8260, Val loss: 0.9413, Val acc: 0.4875
# Epoch [18/300], Train loss: 0.9215, Val loss: 0.9188, Val acc: 0.4376
# Epoch [19/300], Train loss: 1.1218, Val loss: 1.0215, Val acc: 0.4434
# Epoch [20/300], Train loss: 0.8858, Val loss: 0.9610, Val acc: 0.4875
# Epoch [21/300], Train loss: 0.9081, Val loss: 0.9350, Val acc: 0.4875
# Epoch [22/300], Train loss: 0.9692, Val loss: 0.9527, Val acc: 0.5336
# Epoch [23/300], Train loss: 0.9236, Val loss: 0.9219, Val acc: 0.5029
# Epoch [24/300], Train loss: 1.1096, Val loss: 1.1681, Val acc: 0.5451
# Epoch [25/300], Train loss: 1.2140, Val loss: 0.9312, Val acc: 0.4491
# Epoch [26/300], Train loss: 0.9872, Val loss: 0.9697, Val acc: 0.4875
# Epoch [27/300], Train loss: 1.0731, Val loss: 0.9323, Val acc: 0.4914
# Epoch [28/300], Train loss: 0.8693, Val loss: 0.9288, Val acc: 0.4971
# Epoch [29/300], Train loss: 0.9889, Val loss: 0.9358, Val acc: 0.4357
# Epoch [30/300], Train loss: 0.8891, Val loss: 0.9138, Val acc: 0.4952
# Epoch [31/300], Train loss: 0.9657, Val loss: 0.9729, Val acc: 0.4875
# Epoch [32/300], Train loss: 0.9880, Val loss: 0.9712, Val acc: 0.5393
# Epoch [33/300], Train loss: 1.0105, Val loss: 0.9989, Val acc: 0.5413
# Epoch [34/300], Train loss: 1.0830, Val loss: 1.0771, Val acc: 0.5470
# Epoch [35/300], Train loss: 1.0564, Val loss: 0.9148, Val acc: 0.5393
# Epoch [36/300], Train loss: 0.9631, Val loss: 1.1043, Val acc: 0.5048
# Epoch [37/300], Train loss: 1.0591, Val loss: 0.9238, Val acc: 0.4875
# Epoch [38/300], Train loss: 0.9339, Val loss: 0.9493, Val acc: 0.5413
# Epoch [39/300], Train loss: 0.9142, Val loss: 0.9275, Val acc: 0.4683
# Epoch [40/300], Train loss: 0.9101, Val loss: 0.9646, Val acc: 0.5163
# Epoch [41/300], Train loss: 1.0077, Val loss: 0.9626, Val acc: 0.4587
# Epoch [42/300], Train loss: 1.0122, Val loss: 0.9149, Val acc: 0.4088
# Epoch [43/300], Train loss: 0.9683, Val loss: 1.0354, Val acc: 0.4875
# Epoch [44/300], Train loss: 1.0111, Val loss: 0.9781, Val acc: 0.4357
# Epoch [45/300], Train loss: 0.9355, Val loss: 0.9077, Val acc: 0.5048
# Epoch [46/300], Train loss: 1.0183, Val loss: 0.9202, Val acc: 0.5010
# Epoch [47/300], Train loss: 0.8192, Val loss: 0.9158, Val acc: 0.4856
# Epoch [48/300], Train loss: 0.9869, Val loss: 0.9780, Val acc: 0.5086
# Epoch [49/300], Train loss: 1.2047, Val loss: 0.9489, Val acc: 0.5470
# Epoch [50/300], Train loss: 0.9016, Val loss: 0.9128, Val acc: 0.5432
# Epoch [51/300], Train loss: 0.9038, Val loss: 0.9061, Val acc: 0.4626
# Epoch [52/300], Train loss: 0.8187, Val loss: 0.9541, Val acc: 0.4875
# Epoch [53/300], Train loss: 0.9587, Val loss: 0.9271, Val acc: 0.5605
# Epoch [54/300], Train loss: 0.9816, Val loss: 0.9252, Val acc: 0.4434
# Epoch [55/300], Train loss: 1.0002, Val loss: 1.0226, Val acc: 0.5413
# Epoch [56/300], Train loss: 0.9152, Val loss: 1.1410, Val acc: 0.4971
# Epoch [57/300], Train loss: 0.8149, Val loss: 0.9665, Val acc: 0.5451
# Epoch [58/300], Train loss: 0.8745, Val loss: 1.0492, Val acc: 0.5106
# Epoch [59/300], Train loss: 0.8806, Val loss: 1.1237, Val acc: 0.5528
# Epoch [60/300], Train loss: 1.0843, Val loss: 0.9673, Val acc: 0.5125
# Epoch [61/300], Train loss: 0.9422, Val loss: 0.9355, Val acc: 0.4894
# Epoch [62/300], Train loss: 1.1665, Val loss: 0.8978, Val acc: 0.4760
# Epoch [63/300], Train loss: 1.0305, Val loss: 0.9472, Val acc: 0.5298
# Epoch [64/300], Train loss: 0.8630, Val loss: 0.9938, Val acc: 0.5106
# Epoch [65/300], Train loss: 1.1643, Val loss: 1.0997, Val acc: 0.5163
# Epoch [66/300], Train loss: 0.7986, Val loss: 1.0777, Val acc: 0.5451
# Epoch [67/300], Train loss: 0.8570, Val loss: 0.9425, Val acc: 0.4856
# Epoch [68/300], Train loss: 0.9188, Val loss: 0.9130, Val acc: 0.4952
# Epoch [69/300], Train loss: 0.8788, Val loss: 0.9162, Val acc: 0.5509
# Epoch [70/300], Train loss: 0.8079, Val loss: 1.1496, Val acc: 0.5451
# Epoch [71/300], Train loss: 0.9807, Val loss: 0.9521, Val acc: 0.4357
# Epoch [72/300], Train loss: 0.9514, Val loss: 0.9148, Val acc: 0.5029
# Epoch [73/300], Train loss: 1.2031, Val loss: 0.9057, Val acc: 0.4031
# Epoch [74/300], Train loss: 0.8483, Val loss: 1.0344, Val acc: 0.5489
# Epoch [75/300], Train loss: 1.0565, Val loss: 0.9067, Val acc: 0.4971
# Epoch [76/300], Train loss: 1.0452, Val loss: 0.9078, Val acc: 0.4549
# Epoch [77/300], Train loss: 0.9070, Val loss: 0.9152, Val acc: 0.5605
# Epoch [78/300], Train loss: 1.1666, Val loss: 0.9693, Val acc: 0.5432
# Epoch [79/300], Train loss: 1.0711, Val loss: 0.9558, Val acc: 0.4319
# Epoch [80/300], Train loss: 0.8270, Val loss: 0.9178, Val acc: 0.5605
# Epoch [81/300], Train loss: 0.9260, Val loss: 0.9052, Val acc: 0.5048
# Epoch [82/300], Train loss: 0.8703, Val loss: 0.9308, Val acc: 0.4280
# Epoch [83/300], Train loss: 0.9747, Val loss: 0.9532, Val acc: 0.4203
# Epoch [84/300], Train loss: 1.3933, Val loss: 1.3872, Val acc: 0.4645
# Epoch [85/300], Train loss: 0.9759, Val loss: 0.9420, Val acc: 0.5605
# Epoch [86/300], Train loss: 0.8832, Val loss: 0.9319, Val acc: 0.3935
# Epoch [87/300], Train loss: 1.0083, Val loss: 0.9587, Val acc: 0.5470
# Epoch [88/300], Train loss: 0.9844, Val loss: 1.0133, Val acc: 0.5489
# Epoch [89/300], Train loss: 1.0793, Val loss: 0.9427, Val acc: 0.4798
# Epoch [90/300], Train loss: 0.9226, Val loss: 0.9657, Val acc: 0.4914
# Epoch [91/300], Train loss: 0.9737, Val loss: 0.9223, Val acc: 0.5624
# Epoch [92/300], Train loss: 0.8825, Val loss: 0.9134, Val acc: 0.3954
# Epoch [93/300], Train loss: 0.8458, Val loss: 0.9005, Val acc: 0.5106
# Epoch [94/300], Train loss: 0.9994, Val loss: 0.9070, Val acc: 0.5240
# Epoch [95/300], Train loss: 0.9965, Val loss: 0.9821, Val acc: 0.5566
# Epoch [96/300], Train loss: 0.8373, Val loss: 0.9213, Val acc: 0.4741
# Epoch [97/300], Train loss: 0.9123, Val loss: 0.9137, Val acc: 0.5624
# Epoch [98/300], Train loss: 0.7836, Val loss: 0.9472, Val acc: 0.4971
# Epoch [99/300], Train loss: 0.9055, Val loss: 1.0305, Val acc: 0.5470
# Epoch [100/300], Train loss: 0.7636, Val loss: 1.0902, Val acc: 0.4069
# Epoch [101/300], Train loss: 0.9812, Val loss: 0.9961, Val acc: 0.5393
# Epoch [102/300], Train loss: 1.1652, Val loss: 0.9761, Val acc: 0.4184
# Epoch [103/300], Train loss: 1.0331, Val loss: 0.9779, Val acc: 0.5470
# Epoch [104/300], Train loss: 0.9061, Val loss: 0.9683, Val acc: 0.4856
# Epoch [105/300], Train loss: 0.8385, Val loss: 0.9517, Val acc: 0.5336
# Epoch [106/300], Train loss: 1.0054, Val loss: 0.9530, Val acc: 0.4645
# Epoch [107/300], Train loss: 0.8836, Val loss: 0.9260, Val acc: 0.4415
# Epoch [108/300], Train loss: 0.9807, Val loss: 0.9805, Val acc: 0.4568
# Epoch [109/300], Train loss: 0.8943, Val loss: 0.9275, Val acc: 0.5106
# Epoch [110/300], Train loss: 1.1755, Val loss: 1.1279, Val acc: 0.5413
# Epoch [111/300], Train loss: 0.7726, Val loss: 1.0582, Val acc: 0.5566
# Epoch [112/300], Train loss: 1.0608, Val loss: 0.9122, Val acc: 0.4607
# Epoch [113/300], Train loss: 0.8747, Val loss: 0.9262, Val acc: 0.5585
# Epoch [114/300], Train loss: 0.8917, Val loss: 0.9405, Val acc: 0.5067
# Epoch [115/300], Train loss: 0.9095, Val loss: 0.9746, Val acc: 0.5470
# Epoch [116/300], Train loss: 1.0196, Val loss: 0.9380, Val acc: 0.5470
# Epoch [117/300], Train loss: 0.7976, Val loss: 0.8981, Val acc: 0.4107
# Epoch [118/300], Train loss: 0.9960, Val loss: 0.9105, Val acc: 0.4818
# Epoch [119/300], Train loss: 1.0886, Val loss: 1.0965, Val acc: 0.4299
# Epoch [120/300], Train loss: 1.6052, Val loss: 0.9002, Val acc: 0.4203
# Epoch [121/300], Train loss: 1.0306, Val loss: 1.0306, Val acc: 0.4856
# Epoch [122/300], Train loss: 1.0382, Val loss: 0.9332, Val acc: 0.5106
# Epoch [123/300], Train loss: 1.1576, Val loss: 1.0062, Val acc: 0.5470
# Epoch [124/300], Train loss: 0.9711, Val loss: 1.1017, Val acc: 0.4933
# Epoch [125/300], Train loss: 0.9000, Val loss: 0.9290, Val acc: 0.5106
# Epoch [126/300], Train loss: 1.1671, Val loss: 0.9660, Val acc: 0.5451
# Epoch [127/300], Train loss: 0.9593, Val loss: 0.9667, Val acc: 0.5278
# Epoch [128/300], Train loss: 0.8558, Val loss: 1.0199, Val acc: 0.5336
# Epoch [129/300], Train loss: 0.9070, Val loss: 0.9219, Val acc: 0.5547
# Epoch [130/300], Train loss: 1.0696, Val loss: 0.9306, Val acc: 0.5489
# Epoch [131/300], Train loss: 0.9480, Val loss: 0.9960, Val acc: 0.4952
# Epoch [132/300], Train loss: 0.8836, Val loss: 0.9419, Val acc: 0.5432
# Epoch [133/300], Train loss: 0.9086, Val loss: 0.9366, Val acc: 0.4203
# Epoch [134/300], Train loss: 1.0021, Val loss: 0.9047, Val acc: 0.4702
# Epoch [135/300], Train loss: 0.8313, Val loss: 0.9139, Val acc: 0.5509
# Epoch [136/300], Train loss: 0.9734, Val loss: 0.9209, Val acc: 0.5605
# Epoch [137/300], Train loss: 0.8874, Val loss: 0.9204, Val acc: 0.4914
# Epoch [138/300], Train loss: 0.9053, Val loss: 1.0339, Val acc: 0.5413
# Epoch [139/300], Train loss: 0.9950, Val loss: 1.0780, Val acc: 0.5355
# Epoch [140/300], Train loss: 0.8408, Val loss: 0.9519, Val acc: 0.5374
# Epoch [141/300], Train loss: 0.8684, Val loss: 0.9025, Val acc: 0.4722
# Epoch [142/300], Train loss: 0.9666, Val loss: 0.9815, Val acc: 0.4875
# Epoch [143/300], Train loss: 1.0115, Val loss: 1.0420, Val acc: 0.4914
# Epoch [144/300], Train loss: 0.8615, Val loss: 0.9121, Val acc: 0.5086
# Epoch [145/300], Train loss: 0.8889, Val loss: 0.9137, Val acc: 0.5643
# Epoch [146/300], Train loss: 1.1342, Val loss: 0.9187, Val acc: 0.5182
# Epoch [147/300], Train loss: 0.9145, Val loss: 0.9342, Val acc: 0.4914
# Epoch [148/300], Train loss: 0.8698, Val loss: 0.9486, Val acc: 0.4856
# Epoch [149/300], Train loss: 0.9128, Val loss: 1.0583, Val acc: 0.5355
# Epoch [150/300], Train loss: 0.9213, Val loss: 0.9503, Val acc: 0.5470
# Epoch [151/300], Train loss: 1.0735, Val loss: 0.9046, Val acc: 0.5662
# Epoch [152/300], Train loss: 0.9482, Val loss: 0.9744, Val acc: 0.4491
# Epoch [153/300], Train loss: 0.8325, Val loss: 0.9570, Val acc: 0.5681
# Epoch [154/300], Train loss: 0.9480, Val loss: 0.9422, Val acc: 0.5355
# Epoch [155/300], Train loss: 1.3019, Val loss: 1.2236, Val acc: 0.5355
# Epoch [156/300], Train loss: 0.8159, Val loss: 0.9077, Val acc: 0.5393
# Epoch [157/300], Train loss: 0.9234, Val loss: 0.9053, Val acc: 0.5317
# Epoch [158/300], Train loss: 0.9829, Val loss: 0.9022, Val acc: 0.5355
# Epoch [159/300], Train loss: 1.0570, Val loss: 1.0752, Val acc: 0.5374
# Epoch [160/300], Train loss: 1.0024, Val loss: 0.9349, Val acc: 0.4933
# Epoch [161/300], Train loss: 0.9845, Val loss: 0.9124, Val acc: 0.4894
# Epoch [162/300], Train loss: 1.1082, Val loss: 0.9453, Val acc: 0.5470
# Epoch [163/300], Train loss: 1.1524, Val loss: 1.0016, Val acc: 0.5451
# Epoch [164/300], Train loss: 1.0209, Val loss: 1.0017, Val acc: 0.4395
# Epoch [165/300], Train loss: 0.9649, Val loss: 0.9682, Val acc: 0.5067
# Epoch [166/300], Train loss: 1.2496, Val loss: 0.9465, Val acc: 0.5067
# Epoch [167/300], Train loss: 1.1437, Val loss: 0.9258, Val acc: 0.5432
# Epoch [168/300], Train loss: 1.0397, Val loss: 1.0694, Val acc: 0.5106
# Epoch [169/300], Train loss: 0.8038, Val loss: 0.9041, Val acc: 0.5585
# Epoch [170/300], Train loss: 0.8683, Val loss: 0.9168, Val acc: 0.4933
# Epoch [171/300], Train loss: 0.8390, Val loss: 0.9540, Val acc: 0.5106
# Epoch [172/300], Train loss: 1.1118, Val loss: 0.8995, Val acc: 0.5374
# Epoch [173/300], Train loss: 0.9146, Val loss: 0.9481, Val acc: 0.5547
# Epoch [174/300], Train loss: 0.8513, Val loss: 0.9344, Val acc: 0.5067
# Epoch [175/300], Train loss: 1.0246, Val loss: 0.9580, Val acc: 0.4933
# Epoch [176/300], Train loss: 0.9224, Val loss: 0.9642, Val acc: 0.5067
# Epoch [177/300], Train loss: 0.8477, Val loss: 0.9353, Val acc: 0.5509
# Epoch [178/300], Train loss: 0.8896, Val loss: 0.9588, Val acc: 0.4933
# Epoch [179/300], Train loss: 1.1389, Val loss: 0.9007, Val acc: 0.5086
# Epoch [180/300], Train loss: 0.8689, Val loss: 0.9360, Val acc: 0.5355
# Epoch [181/300], Train loss: 1.2144, Val loss: 0.9808, Val acc: 0.5374
# Epoch [182/300], Train loss: 0.9485, Val loss: 0.9310, Val acc: 0.5106
# Epoch [183/300], Train loss: 0.9656, Val loss: 0.9358, Val acc: 0.5470
# Epoch [184/300], Train loss: 0.7742, Val loss: 0.9680, Val acc: 0.4875
# Epoch [185/300], Train loss: 1.0036, Val loss: 0.9725, Val acc: 0.5106
# Epoch [186/300], Train loss: 1.0567, Val loss: 0.9045, Val acc: 0.5086
# Epoch [187/300], Train loss: 0.8635, Val loss: 0.9045, Val acc: 0.5470
# Epoch [188/300], Train loss: 0.9339, Val loss: 0.9459, Val acc: 0.5355
# Epoch [189/300], Train loss: 0.9753, Val loss: 0.9492, Val acc: 0.5470
# Epoch [190/300], Train loss: 1.0702, Val loss: 0.9504, Val acc: 0.4779
# Epoch [191/300], Train loss: 0.8924, Val loss: 0.9061, Val acc: 0.4894
# Epoch [192/300], Train loss: 0.9358, Val loss: 0.9503, Val acc: 0.4971
# Epoch [193/300], Train loss: 0.8785, Val loss: 0.9181, Val acc: 0.5086
# Epoch [194/300], Train loss: 1.2014, Val loss: 1.0097, Val acc: 0.5221
# Epoch [195/300], Train loss: 1.0291, Val loss: 1.0729, Val acc: 0.5106
# Epoch [196/300], Train loss: 1.4317, Val loss: 1.0990, Val acc: 0.5106
# Epoch [197/300], Train loss: 1.0182, Val loss: 0.9714, Val acc: 0.4568
# Epoch [198/300], Train loss: 0.8742, Val loss: 0.9393, Val acc: 0.5163
# Epoch [199/300], Train loss: 0.7901, Val loss: 0.9337, Val acc: 0.4338
# Epoch [200/300], Train loss: 0.8765, Val loss: 0.9200, Val acc: 0.5528
# Epoch [201/300], Train loss: 1.0475, Val loss: 0.9204, Val acc: 0.5643
# Epoch [202/300], Train loss: 0.9361, Val loss: 0.9148, Val acc: 0.5528
# Epoch [203/300], Train loss: 0.8172, Val loss: 0.9463, Val acc: 0.5528
# Epoch [204/300], Train loss: 0.9629, Val loss: 0.9684, Val acc: 0.5451
# Epoch [205/300], Train loss: 0.8011, Val loss: 0.8983, Val acc: 0.4818
# Epoch [206/300], Train loss: 0.9766, Val loss: 0.9461, Val acc: 0.4914
# Epoch [207/300], Train loss: 1.0654, Val loss: 0.9892, Val acc: 0.5451
# Epoch [208/300], Train loss: 0.8905, Val loss: 0.9266, Val acc: 0.5470
# Epoch [209/300], Train loss: 1.0162, Val loss: 0.9133, Val acc: 0.5413
# Epoch [210/300], Train loss: 0.8311, Val loss: 0.9313, Val acc: 0.4434
# Epoch [211/300], Train loss: 1.0017, Val loss: 0.9118, Val acc: 0.5144
# Epoch [212/300], Train loss: 0.7937, Val loss: 0.9227, Val acc: 0.4971
# Epoch [213/300], Train loss: 1.1494, Val loss: 1.0193, Val acc: 0.4856
# Epoch [214/300], Train loss: 1.1988, Val loss: 0.9341, Val acc: 0.4894
# Epoch [215/300], Train loss: 0.9287, Val loss: 0.9930, Val acc: 0.4856
# Epoch [216/300], Train loss: 0.9307, Val loss: 0.8984, Val acc: 0.4472
# Epoch [217/300], Train loss: 0.9535, Val loss: 0.9136, Val acc: 0.5451
# Epoch [218/300], Train loss: 0.8433, Val loss: 0.9214, Val acc: 0.5470
# Epoch [219/300], Train loss: 1.0572, Val loss: 0.9215, Val acc: 0.5547
# Epoch [220/300], Train loss: 0.9730, Val loss: 0.9556, Val acc: 0.5067
# Epoch [221/300], Train loss: 0.8967, Val loss: 0.9135, Val acc: 0.5624
# Epoch [222/300], Train loss: 0.8209, Val loss: 1.0105, Val acc: 0.4223
# Epoch [223/300], Train loss: 1.0332, Val loss: 0.9802, Val acc: 0.4434
# Epoch [224/300], Train loss: 1.2489, Val loss: 0.9020, Val acc: 0.4549
# Epoch [225/300], Train loss: 1.1814, Val loss: 1.0552, Val acc: 0.5451
# Epoch [226/300], Train loss: 1.0126, Val loss: 0.9222, Val acc: 0.4933
# Epoch [227/300], Train loss: 0.7654, Val loss: 0.9182, Val acc: 0.5259
# Epoch [228/300], Train loss: 1.2046, Val loss: 0.9696, Val acc: 0.5701
# Epoch [229/300], Train loss: 0.8506, Val loss: 1.0075, Val acc: 0.4875
# Epoch [230/300], Train loss: 1.0275, Val loss: 0.9149, Val acc: 0.5624
# Epoch [231/300], Train loss: 0.9528, Val loss: 0.9668, Val acc: 0.4088
# Epoch [232/300], Train loss: 0.9510, Val loss: 0.9555, Val acc: 0.5662
# Epoch [233/300], Train loss: 0.8025, Val loss: 0.9682, Val acc: 0.5470
# Epoch [234/300], Train loss: 0.8968, Val loss: 0.9246, Val acc: 0.5106
# Epoch [235/300], Train loss: 0.6983, Val loss: 1.0711, Val acc: 0.5470
# Epoch [236/300], Train loss: 1.1741, Val loss: 0.9078, Val acc: 0.5317
# Epoch [237/300], Train loss: 0.9412, Val loss: 0.9672, Val acc: 0.5451
# Epoch [238/300], Train loss: 0.9915, Val loss: 0.8983, Val acc: 0.3973
# Epoch [239/300], Train loss: 0.9575, Val loss: 0.9271, Val acc: 0.5528
# Epoch [240/300], Train loss: 1.0824, Val loss: 0.9872, Val acc: 0.4875
# Epoch [241/300], Train loss: 0.7592, Val loss: 0.9137, Val acc: 0.4952
# Epoch [242/300], Train loss: 0.8879, Val loss: 0.9156, Val acc: 0.5509
# Epoch [243/300], Train loss: 0.8166, Val loss: 0.9071, Val acc: 0.5413
# Epoch [244/300], Train loss: 0.9678, Val loss: 0.9314, Val acc: 0.5106
# Epoch [245/300], Train loss: 0.8200, Val loss: 0.9842, Val acc: 0.5086
# Epoch [246/300], Train loss: 0.9084, Val loss: 0.9181, Val acc: 0.5106
# Epoch [247/300], Train loss: 0.9649, Val loss: 1.0133, Val acc: 0.5470
# Epoch [248/300], Train loss: 0.9648, Val loss: 0.9780, Val acc: 0.5374
# Epoch [249/300], Train loss: 0.9467, Val loss: 0.9546, Val acc: 0.5106
# Epoch [250/300], Train loss: 0.9076, Val loss: 0.9640, Val acc: 0.5278
# Epoch [251/300], Train loss: 1.0647, Val loss: 0.9321, Val acc: 0.5336
# Epoch [252/300], Train loss: 1.0225, Val loss: 0.9405, Val acc: 0.4971
# Epoch [253/300], Train loss: 1.0670, Val loss: 1.1192, Val acc: 0.5470
# Epoch [254/300], Train loss: 0.9536, Val loss: 0.9811, Val acc: 0.5106
# Epoch [255/300], Train loss: 0.7973, Val loss: 0.9662, Val acc: 0.5374
# Epoch [256/300], Train loss: 1.0386, Val loss: 0.9455, Val acc: 0.4818
# Epoch [257/300], Train loss: 0.9394, Val loss: 0.9364, Val acc: 0.5086
# Epoch [258/300], Train loss: 0.8735, Val loss: 0.9135, Val acc: 0.5106
# Epoch [259/300], Train loss: 1.1280, Val loss: 0.9586, Val acc: 0.5355
# Epoch [260/300], Train loss: 1.0746, Val loss: 0.8986, Val acc: 0.4702
# Epoch [261/300], Train loss: 0.9618, Val loss: 0.9103, Val acc: 0.4741
# Epoch [262/300], Train loss: 0.9738, Val loss: 0.9055, Val acc: 0.5086
# Epoch [263/300], Train loss: 1.0375, Val loss: 0.9537, Val acc: 0.5374
# Epoch [264/300], Train loss: 0.9597, Val loss: 0.9673, Val acc: 0.4779
# Epoch [265/300], Train loss: 1.0544, Val loss: 0.9643, Val acc: 0.5163
# Epoch [266/300], Train loss: 0.8816, Val loss: 0.9151, Val acc: 0.5489
# Epoch [267/300], Train loss: 1.0407, Val loss: 0.9529, Val acc: 0.5413
# Epoch [268/300], Train loss: 1.0351, Val loss: 0.9574, Val acc: 0.5086
# Epoch [269/300], Train loss: 0.9217, Val loss: 0.9587, Val acc: 0.5451
# Epoch [270/300], Train loss: 1.0081, Val loss: 0.9951, Val acc: 0.5336
# Epoch [271/300], Train loss: 0.9075, Val loss: 0.9320, Val acc: 0.5336
# Epoch [272/300], Train loss: 1.0218, Val loss: 1.0855, Val acc: 0.5470
# Epoch [273/300], Train loss: 0.8503, Val loss: 0.9800, Val acc: 0.5413
# Epoch [274/300], Train loss: 0.7924, Val loss: 0.9149, Val acc: 0.5413
# Epoch [275/300], Train loss: 0.8820, Val loss: 1.1386, Val acc: 0.5470
# Epoch [276/300], Train loss: 0.9038, Val loss: 0.9348, Val acc: 0.5067
# Epoch [277/300], Train loss: 0.8298, Val loss: 0.9294, Val acc: 0.5451
# Epoch [278/300], Train loss: 1.2371, Val loss: 0.9548, Val acc: 0.5585
# Epoch [279/300], Train loss: 1.0888, Val loss: 0.9273, Val acc: 0.4971
# Epoch [280/300], Train loss: 0.9905, Val loss: 1.0228, Val acc: 0.5470
# Epoch [281/300], Train loss: 1.0690, Val loss: 0.9286, Val acc: 0.5106
# Epoch [282/300], Train loss: 0.9001, Val loss: 0.9498, Val acc: 0.5470
# Epoch [283/300], Train loss: 0.9543, Val loss: 0.9603, Val acc: 0.5106
# Epoch [284/300], Train loss: 1.0471, Val loss: 0.9571, Val acc: 0.5106
# Epoch [285/300], Train loss: 1.0357, Val loss: 0.9359, Val acc: 0.5470
# Epoch [286/300], Train loss: 1.0285, Val loss: 0.9259, Val acc: 0.5470
# Epoch [287/300], Train loss: 0.9347, Val loss: 0.9964, Val acc: 0.5393
# Epoch [288/300], Train loss: 0.8915, Val loss: 0.9066, Val acc: 0.5067
# Epoch [289/300], Train loss: 1.1190, Val loss: 0.9897, Val acc: 0.4856
# Epoch [290/300], Train loss: 1.0759, Val loss: 1.0132, Val acc: 0.4875
# Epoch [291/300], Train loss: 0.8867, Val loss: 1.0180, Val acc: 0.5029
# Epoch [292/300], Train loss: 1.0157, Val loss: 1.0189, Val acc: 0.5355
# Epoch [293/300], Train loss: 0.9206, Val loss: 0.9848, Val acc: 0.4856
# Epoch [294/300], Train loss: 1.0357, Val loss: 0.9700, Val acc: 0.4990
# Epoch [295/300], Train loss: 0.9986, Val loss: 0.9754, Val acc: 0.5720
# Epoch [296/300], Train loss: 0.9671, Val loss: 0.9599, Val acc: 0.4856
# Epoch [297/300], Train loss: 1.1089, Val loss: 0.9278, Val acc: 0.4933
# Epoch [298/300], Train loss: 0.8487, Val loss: 1.2372, Val acc: 0.5010
# Epoch [299/300], Train loss: 1.0083, Val loss: 1.0573, Val acc: 0.5432
# Epoch [300/300], Train loss: 0.9527, Val loss: 1.0147, Val acc: 0.5470

# %%
assert isinstance(tiny_model, nn.Module), "tiny_model should be a torch.nn.Module"
test_model_output_shape(tiny_model)

# %% [markdown]
# Now, draw the decision regions of the network as you did in the previous section. Before running the code, think about what you expect to see. What will the regions look like? How will they differ from the previous ones?

# %%
plot_decision_region(
    tiny_model,
    dataset_train.x,
    dataset_train.y,
    dataset_val.x,
    dataset_val.y,
)

# %% [markdown]
# Are the decision regions any different? Why/why not? What does this tell you about the model capacity and its ability to generalize?

# %% [markdown]
# **Your answer:** Yes. The tiny model produces only straight, large decision boundaries because it consists of a single linear layer. It cannot capture the detailed geographical clusters or overlapping regions of the classes. Compared with the previous neural network, its regions are much simpler and it is more likely to underfit the data.

# %% [markdown]
# Next, create a neural network `large_model` with many layers and/or hidden units. Try to maximize the training accuracy (0.7-0.8). Getting these models to converge might be a bit tricky, so you might have to adjust the learning rate, the optimizer, etc. Also, might be easier to have a wide model (large number of hidden units, say 1024 per layer) than a deep model (more than 4 layers).
#
# Feel free to experiment, but if you get stuck, our model is a MLP with an input layer, 4 hidden layers with 1024 units each, and an output layer. We used the ReLU activation function between each layer and a softmax for the output layer. We used the Adam optimizer with a learning rate of 0.003 and a batch size of 512. We trained for at least a few hundred epochs. Also, normalizing the input can be helpful (zero mean and unit variance).

# %%
large_model = nn.Sequential(
    nn.Linear(2, 256),
    nn.ReLU(),
    nn.Linear(256, 256),
    nn.ReLU(),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Linear(64, 3),
).to(device)

large_optimizer = torch.optim.Adam(large_model.parameters(), lr=0.003)

train_model(
    model=large_model,
    optimizer=large_optimizer,
    loss_fn=nn.CrossEntropyLoss(),
    num_epochs=250,
    train_dataloader=loader_train,
    val_dataloader=loader_val,
    device=device,
)
# Out:
# Epoch [1/250], Train loss: 0.8672, Val loss: 0.8594, Val acc: 0.5528
# Epoch [2/250], Train loss: 0.8184, Val loss: 0.8644, Val acc: 0.6756
# Epoch [3/250], Train loss: 0.7475, Val loss: 0.8163, Val acc: 0.6353
# Epoch [4/250], Train loss: 0.7748, Val loss: 0.8072, Val acc: 0.6372
# Epoch [5/250], Train loss: 0.8166, Val loss: 0.8057, Val acc: 0.6488
# Epoch [6/250], Train loss: 0.7295, Val loss: 0.8117, Val acc: 0.6507
# Epoch [7/250], Train loss: 0.6890, Val loss: 0.8047, Val acc: 0.6737
# Epoch [8/250], Train loss: 0.7817, Val loss: 0.8205, Val acc: 0.6392
# Epoch [9/250], Train loss: 0.7127, Val loss: 0.8053, Val acc: 0.6526
# Epoch [10/250], Train loss: 0.6532, Val loss: 0.7984, Val acc: 0.6334
# Epoch [11/250], Train loss: 0.7750, Val loss: 0.8006, Val acc: 0.6526
# Epoch [12/250], Train loss: 0.7733, Val loss: 0.7870, Val acc: 0.6641
# Epoch [13/250], Train loss: 0.8280, Val loss: 0.8055, Val acc: 0.6430
# Epoch [14/250], Train loss: 0.7323, Val loss: 0.7867, Val acc: 0.6737
# Epoch [15/250], Train loss: 0.9017, Val loss: 0.7937, Val acc: 0.6507
# Epoch [16/250], Train loss: 0.6441, Val loss: 0.7834, Val acc: 0.6430
# Epoch [17/250], Train loss: 0.7329, Val loss: 0.7830, Val acc: 0.6679
# Epoch [18/250], Train loss: 0.7657, Val loss: 0.7967, Val acc: 0.6603
# Epoch [19/250], Train loss: 0.8572, Val loss: 0.7840, Val acc: 0.6411
# Epoch [20/250], Train loss: 0.8073, Val loss: 0.7874, Val acc: 0.6430
# Epoch [21/250], Train loss: 0.6358, Val loss: 0.7881, Val acc: 0.6334
# Epoch [22/250], Train loss: 0.7965, Val loss: 0.7918, Val acc: 0.6334
# Epoch [23/250], Train loss: 0.7261, Val loss: 0.7857, Val acc: 0.6488
# Epoch [24/250], Train loss: 0.7205, Val loss: 0.7704, Val acc: 0.6488
# Epoch [25/250], Train loss: 0.6863, Val loss: 0.7756, Val acc: 0.6430
# Epoch [26/250], Train loss: 0.7621, Val loss: 0.8098, Val acc: 0.5835
# Epoch [27/250], Train loss: 0.8729, Val loss: 0.7846, Val acc: 0.6430
# Epoch [28/250], Train loss: 0.6849, Val loss: 0.7904, Val acc: 0.6622
# Epoch [29/250], Train loss: 0.8381, Val loss: 0.7785, Val acc: 0.6353
# Epoch [30/250], Train loss: 0.6912, Val loss: 0.7811, Val acc: 0.6507
# Epoch [31/250], Train loss: 0.9948, Val loss: 0.7762, Val acc: 0.6468
# Epoch [32/250], Train loss: 0.7567, Val loss: 0.7765, Val acc: 0.6507
# Epoch [33/250], Train loss: 0.6793, Val loss: 0.7752, Val acc: 0.6430
# Epoch [34/250], Train loss: 0.7566, Val loss: 0.8085, Val acc: 0.6392
# Epoch [35/250], Train loss: 0.8018, Val loss: 0.7774, Val acc: 0.6430
# Epoch [36/250], Train loss: 0.7781, Val loss: 0.7888, Val acc: 0.6334
# Epoch [37/250], Train loss: 0.7285, Val loss: 0.7824, Val acc: 0.6430
# Epoch [38/250], Train loss: 0.7967, Val loss: 0.7733, Val acc: 0.6430
# Epoch [39/250], Train loss: 0.7965, Val loss: 0.7957, Val acc: 0.6641
# Epoch [40/250], Train loss: 0.8320, Val loss: 0.7803, Val acc: 0.6353
# Epoch [41/250], Train loss: 0.7609, Val loss: 0.7720, Val acc: 0.6430
# Epoch [42/250], Train loss: 0.8743, Val loss: 0.7752, Val acc: 0.6526
# Epoch [43/250], Train loss: 0.7939, Val loss: 0.8073, Val acc: 0.6334
# Epoch [44/250], Train loss: 0.9271, Val loss: 0.7879, Val acc: 0.6372
# Epoch [45/250], Train loss: 0.8806, Val loss: 0.7775, Val acc: 0.6507
# Epoch [46/250], Train loss: 0.8347, Val loss: 0.7701, Val acc: 0.6430
# Epoch [47/250], Train loss: 0.7808, Val loss: 0.7751, Val acc: 0.6430
# Epoch [48/250], Train loss: 0.7522, Val loss: 0.7840, Val acc: 0.6526
# Epoch [49/250], Train loss: 0.7559, Val loss: 0.7719, Val acc: 0.6430
# Epoch [50/250], Train loss: 0.7433, Val loss: 0.8064, Val acc: 0.6372
# Epoch [51/250], Train loss: 0.7507, Val loss: 0.7781, Val acc: 0.6449
# Epoch [52/250], Train loss: 0.6094, Val loss: 0.7768, Val acc: 0.6468
# Epoch [53/250], Train loss: 0.7877, Val loss: 0.7685, Val acc: 0.6526
# Epoch [54/250], Train loss: 0.8269, Val loss: 0.7784, Val acc: 0.6468
# Epoch [55/250], Train loss: 0.7206, Val loss: 0.7941, Val acc: 0.6353
# Epoch [56/250], Train loss: 0.7159, Val loss: 0.7803, Val acc: 0.6449
# Epoch [57/250], Train loss: 0.7729, Val loss: 0.7713, Val acc: 0.6564
# Epoch [58/250], Train loss: 0.7719, Val loss: 0.7783, Val acc: 0.6564
# Epoch [59/250], Train loss: 0.8990, Val loss: 0.7702, Val acc: 0.6449
# Epoch [60/250], Train loss: 0.6370, Val loss: 0.7715, Val acc: 0.6545
# Epoch [61/250], Train loss: 0.8678, Val loss: 0.7959, Val acc: 0.6372
# Epoch [62/250], Train loss: 0.7973, Val loss: 0.7796, Val acc: 0.6468
# Epoch [63/250], Train loss: 0.8408, Val loss: 0.7756, Val acc: 0.6468
# Epoch [64/250], Train loss: 0.6620, Val loss: 0.7728, Val acc: 0.6526
# Epoch [65/250], Train loss: 0.6709, Val loss: 0.7724, Val acc: 0.6449
# Epoch [66/250], Train loss: 0.5487, Val loss: 0.7718, Val acc: 0.6526
# Epoch [67/250], Train loss: 0.7591, Val loss: 0.7923, Val acc: 0.6526
# Epoch [68/250], Train loss: 0.7163, Val loss: 0.7705, Val acc: 0.6449
# Epoch [69/250], Train loss: 0.6526, Val loss: 0.7746, Val acc: 0.6430
# Epoch [70/250], Train loss: 0.7056, Val loss: 0.7738, Val acc: 0.6430
# Epoch [71/250], Train loss: 0.7471, Val loss: 0.7737, Val acc: 0.6583
# Epoch [72/250], Train loss: 0.7270, Val loss: 0.7788, Val acc: 0.6468
# Epoch [73/250], Train loss: 0.6517, Val loss: 0.7673, Val acc: 0.6526
# Epoch [74/250], Train loss: 0.6764, Val loss: 0.7775, Val acc: 0.6449
# Epoch [75/250], Train loss: 0.8275, Val loss: 0.7679, Val acc: 0.6526
# Epoch [76/250], Train loss: 0.8191, Val loss: 0.7692, Val acc: 0.6545
# Epoch [77/250], Train loss: 0.8236, Val loss: 0.7710, Val acc: 0.6526
# Epoch [78/250], Train loss: 0.8477, Val loss: 0.7785, Val acc: 0.6257
# Epoch [79/250], Train loss: 0.8574, Val loss: 0.7884, Val acc: 0.6353
# Epoch [80/250], Train loss: 0.8212, Val loss: 0.7777, Val acc: 0.6449
# Epoch [81/250], Train loss: 0.6756, Val loss: 0.7681, Val acc: 0.6507
# Epoch [82/250], Train loss: 0.8194, Val loss: 0.7737, Val acc: 0.6449
# Epoch [83/250], Train loss: 0.7807, Val loss: 0.7686, Val acc: 0.6526
# Epoch [84/250], Train loss: 0.7732, Val loss: 0.7719, Val acc: 0.6449
# Epoch [85/250], Train loss: 0.7609, Val loss: 0.7664, Val acc: 0.6468
# Epoch [86/250], Train loss: 0.7732, Val loss: 0.7743, Val acc: 0.6583
# Epoch [87/250], Train loss: 0.6724, Val loss: 0.7752, Val acc: 0.6564
# Epoch [88/250], Train loss: 0.7483, Val loss: 0.8199, Val acc: 0.6372
# Epoch [89/250], Train loss: 0.7600, Val loss: 0.7653, Val acc: 0.6468
# Epoch [90/250], Train loss: 0.7690, Val loss: 0.7684, Val acc: 0.6468
# Epoch [91/250], Train loss: 0.8093, Val loss: 0.7687, Val acc: 0.6468
# Epoch [92/250], Train loss: 0.6759, Val loss: 0.7658, Val acc: 0.6545
# Epoch [93/250], Train loss: 0.7467, Val loss: 0.7657, Val acc: 0.6545
# Epoch [94/250], Train loss: 0.7771, Val loss: 0.7841, Val acc: 0.6545
# Epoch [95/250], Train loss: 0.6979, Val loss: 0.7702, Val acc: 0.6468
# Epoch [96/250], Train loss: 0.7022, Val loss: 0.7742, Val acc: 0.6468
# Epoch [97/250], Train loss: 0.6375, Val loss: 0.7669, Val acc: 0.6660
# Epoch [98/250], Train loss: 0.8285, Val loss: 0.7824, Val acc: 0.6430
# Epoch [99/250], Train loss: 0.6904, Val loss: 0.7737, Val acc: 0.6545
# Epoch [100/250], Train loss: 0.8172, Val loss: 0.7714, Val acc: 0.6526
# Epoch [101/250], Train loss: 0.6732, Val loss: 0.7748, Val acc: 0.6564
# Epoch [102/250], Train loss: 0.8274, Val loss: 0.7724, Val acc: 0.6296
# Epoch [103/250], Train loss: 0.7837, Val loss: 0.7912, Val acc: 0.6392
# Epoch [104/250], Train loss: 0.9699, Val loss: 0.7676, Val acc: 0.6468
# Epoch [105/250], Train loss: 0.6935, Val loss: 0.7692, Val acc: 0.6430
# Epoch [106/250], Train loss: 0.5848, Val loss: 0.7736, Val acc: 0.6545
# Epoch [107/250], Train loss: 0.6469, Val loss: 0.7682, Val acc: 0.6392
# Epoch [108/250], Train loss: 0.6962, Val loss: 0.7694, Val acc: 0.6392
# Epoch [109/250], Train loss: 0.7324, Val loss: 0.7731, Val acc: 0.6411
# Epoch [110/250], Train loss: 0.8418, Val loss: 0.7595, Val acc: 0.6411
# Epoch [111/250], Train loss: 0.7291, Val loss: 0.7633, Val acc: 0.6545
# Epoch [112/250], Train loss: 0.7411, Val loss: 0.7841, Val acc: 0.6296
# Epoch [113/250], Train loss: 0.7147, Val loss: 0.7561, Val acc: 0.6891
# Epoch [114/250], Train loss: 0.6552, Val loss: 0.7774, Val acc: 0.7063
# Epoch [115/250], Train loss: 0.7977, Val loss: 0.7659, Val acc: 0.6468
# Epoch [116/250], Train loss: 0.6691, Val loss: 0.7734, Val acc: 0.6583
# Epoch [117/250], Train loss: 0.9211, Val loss: 0.7587, Val acc: 0.6372
# Epoch [118/250], Train loss: 0.6774, Val loss: 0.7899, Val acc: 0.6449
# Epoch [119/250], Train loss: 0.6216, Val loss: 0.7706, Val acc: 0.6814
# Epoch [120/250], Train loss: 0.5974, Val loss: 0.7654, Val acc: 0.6564
# Epoch [121/250], Train loss: 0.7432, Val loss: 0.7629, Val acc: 0.6353
# Epoch [122/250], Train loss: 0.7055, Val loss: 0.7651, Val acc: 0.6392
# Epoch [123/250], Train loss: 0.8217, Val loss: 0.7660, Val acc: 0.6334
# Epoch [124/250], Train loss: 0.6490, Val loss: 0.7626, Val acc: 0.6411
# Epoch [125/250], Train loss: 0.6690, Val loss: 0.7668, Val acc: 0.6468
# Epoch [126/250], Train loss: 0.7581, Val loss: 0.7620, Val acc: 0.6891
# Epoch [127/250], Train loss: 0.7305, Val loss: 0.7595, Val acc: 0.6276
# Epoch [128/250], Train loss: 0.6475, Val loss: 0.7657, Val acc: 0.6430
# Epoch [129/250], Train loss: 0.7041, Val loss: 0.7639, Val acc: 0.6430
# Epoch [130/250], Train loss: 0.8730, Val loss: 0.7578, Val acc: 0.6507
# Epoch [131/250], Train loss: 0.8384, Val loss: 0.7664, Val acc: 0.6238
# Epoch [132/250], Train loss: 0.7322, Val loss: 0.7641, Val acc: 0.7006
# Epoch [133/250], Train loss: 0.8220, Val loss: 0.7589, Val acc: 0.6583
# Epoch [134/250], Train loss: 0.6722, Val loss: 0.7635, Val acc: 0.6276
# Epoch [135/250], Train loss: 0.6410, Val loss: 0.7653, Val acc: 0.6468
# Epoch [136/250], Train loss: 0.7140, Val loss: 0.7670, Val acc: 0.6468
# Epoch [137/250], Train loss: 0.7769, Val loss: 0.7611, Val acc: 0.6468
# Epoch [138/250], Train loss: 0.6559, Val loss: 0.7646, Val acc: 0.6795
# Epoch [139/250], Train loss: 0.6952, Val loss: 0.7662, Val acc: 0.6545
# Epoch [140/250], Train loss: 0.7509, Val loss: 0.7804, Val acc: 0.6468
# Epoch [141/250], Train loss: 0.6717, Val loss: 0.7659, Val acc: 0.6449
# Epoch [142/250], Train loss: 0.7033, Val loss: 0.7575, Val acc: 0.6871
# Epoch [143/250], Train loss: 0.7948, Val loss: 0.7674, Val acc: 0.6775
# Epoch [144/250], Train loss: 0.8883, Val loss: 0.7682, Val acc: 0.6775
# Epoch [145/250], Train loss: 0.8821, Val loss: 0.7719, Val acc: 0.6430
# Epoch [146/250], Train loss: 0.8402, Val loss: 0.7758, Val acc: 0.6737
# Epoch [147/250], Train loss: 0.7196, Val loss: 0.7552, Val acc: 0.6526
# Epoch [148/250], Train loss: 0.7465, Val loss: 0.7491, Val acc: 0.7063
# Epoch [149/250], Train loss: 0.7505, Val loss: 0.7837, Val acc: 0.6526
# Epoch [150/250], Train loss: 0.7231, Val loss: 0.7808, Val acc: 0.6718
# Epoch [151/250], Train loss: 0.7746, Val loss: 0.7617, Val acc: 0.6583
# Epoch [152/250], Train loss: 0.7161, Val loss: 0.7677, Val acc: 0.6641
# Epoch [153/250], Train loss: 0.7851, Val loss: 0.7598, Val acc: 0.6948
# Epoch [154/250], Train loss: 0.6700, Val loss: 0.7603, Val acc: 0.6468
# Epoch [155/250], Train loss: 0.7249, Val loss: 0.7889, Val acc: 0.6699
# Epoch [156/250], Train loss: 0.6617, Val loss: 0.7646, Val acc: 0.6449
# Epoch [157/250], Train loss: 0.7619, Val loss: 0.7616, Val acc: 0.6468
# Epoch [158/250], Train loss: 0.8149, Val loss: 0.7495, Val acc: 0.6814
# Epoch [159/250], Train loss: 0.8257, Val loss: 0.7654, Val acc: 0.6641
# Epoch [160/250], Train loss: 0.6486, Val loss: 0.7495, Val acc: 0.6372
# Epoch [161/250], Train loss: 0.7304, Val loss: 0.7506, Val acc: 0.6372
# Epoch [162/250], Train loss: 0.7164, Val loss: 0.7709, Val acc: 0.6756
# Epoch [163/250], Train loss: 0.6911, Val loss: 0.7513, Val acc: 0.6372
# Epoch [164/250], Train loss: 0.6879, Val loss: 0.7601, Val acc: 0.6334
# Epoch [165/250], Train loss: 0.8507, Val loss: 0.7610, Val acc: 0.6468
# Epoch [166/250], Train loss: 0.8253, Val loss: 0.7556, Val acc: 0.7006
# Epoch [167/250], Train loss: 0.7426, Val loss: 0.7608, Val acc: 0.6488
# Epoch [168/250], Train loss: 0.6669, Val loss: 0.7461, Val acc: 0.6372
# Epoch [169/250], Train loss: 0.8876, Val loss: 0.7499, Val acc: 0.6545
# Epoch [170/250], Train loss: 0.7445, Val loss: 0.7622, Val acc: 0.6679
# Epoch [171/250], Train loss: 0.7589, Val loss: 0.7552, Val acc: 0.6603
# Epoch [172/250], Train loss: 0.8893, Val loss: 0.7432, Val acc: 0.6814
# Epoch [173/250], Train loss: 0.6028, Val loss: 0.7917, Val acc: 0.6430
# Epoch [174/250], Train loss: 0.9127, Val loss: 0.7615, Val acc: 0.6449
# Epoch [175/250], Train loss: 0.5822, Val loss: 0.7479, Val acc: 0.7140
# Epoch [176/250], Train loss: 0.6658, Val loss: 0.7777, Val acc: 0.6545
# Epoch [177/250], Train loss: 0.6231, Val loss: 0.7573, Val acc: 0.6699
# Epoch [178/250], Train loss: 0.7983, Val loss: 0.7551, Val acc: 0.6737
# Epoch [179/250], Train loss: 0.7297, Val loss: 0.7631, Val acc: 0.6948
# Epoch [180/250], Train loss: 0.6613, Val loss: 0.7685, Val acc: 0.6545
# Epoch [181/250], Train loss: 0.6858, Val loss: 0.7692, Val acc: 0.6737
# Epoch [182/250], Train loss: 0.6872, Val loss: 0.7597, Val acc: 0.6622
# Epoch [183/250], Train loss: 0.7709, Val loss: 0.7577, Val acc: 0.6641
# Epoch [184/250], Train loss: 0.7146, Val loss: 0.7639, Val acc: 0.6641
# Epoch [185/250], Train loss: 0.7400, Val loss: 0.7616, Val acc: 0.6641
# Epoch [186/250], Train loss: 0.7348, Val loss: 0.7576, Val acc: 0.6775
# Epoch [187/250], Train loss: 0.7532, Val loss: 0.7412, Val acc: 0.6699
# Epoch [188/250], Train loss: 0.7247, Val loss: 0.7378, Val acc: 0.6660
# Epoch [189/250], Train loss: 0.6630, Val loss: 0.7602, Val acc: 0.6641
# Epoch [190/250], Train loss: 0.7442, Val loss: 0.7467, Val acc: 0.6564
# Epoch [191/250], Train loss: 0.7907, Val loss: 0.7739, Val acc: 0.6488
# Epoch [192/250], Train loss: 0.8576, Val loss: 0.7699, Val acc: 0.6641
# Epoch [193/250], Train loss: 0.6839, Val loss: 0.7638, Val acc: 0.6679
# Epoch [194/250], Train loss: 0.8135, Val loss: 0.7495, Val acc: 0.6679
# Epoch [195/250], Train loss: 0.8482, Val loss: 0.7475, Val acc: 0.6737
# Epoch [196/250], Train loss: 0.8804, Val loss: 0.7501, Val acc: 0.6660
# Epoch [197/250], Train loss: 0.6665, Val loss: 0.7490, Val acc: 0.6987
# Epoch [198/250], Train loss: 0.8141, Val loss: 0.7696, Val acc: 0.6641
# Epoch [199/250], Train loss: 0.7330, Val loss: 0.7572, Val acc: 0.6775
# Epoch [200/250], Train loss: 0.7842, Val loss: 0.7439, Val acc: 0.6603
# Epoch [201/250], Train loss: 0.5629, Val loss: 0.7454, Val acc: 0.6852
# Epoch [202/250], Train loss: 0.6682, Val loss: 0.7442, Val acc: 0.6852
# Epoch [203/250], Train loss: 0.8482, Val loss: 0.7564, Val acc: 0.6718
# Epoch [204/250], Train loss: 0.7201, Val loss: 0.7543, Val acc: 0.6699
# Epoch [205/250], Train loss: 0.7961, Val loss: 0.7583, Val acc: 0.6564
# Epoch [206/250], Train loss: 0.7969, Val loss: 0.7534, Val acc: 0.6622
# Epoch [207/250], Train loss: 0.7151, Val loss: 0.7420, Val acc: 0.6987
# Epoch [208/250], Train loss: 0.7320, Val loss: 0.7544, Val acc: 0.6545
# Epoch [209/250], Train loss: 0.7028, Val loss: 0.7562, Val acc: 0.6948
# Epoch [210/250], Train loss: 0.6895, Val loss: 0.7476, Val acc: 0.6507
# Epoch [211/250], Train loss: 0.6667, Val loss: 0.7613, Val acc: 0.6795
# Epoch [212/250], Train loss: 0.7134, Val loss: 0.7545, Val acc: 0.6699
# Epoch [213/250], Train loss: 0.7973, Val loss: 0.7460, Val acc: 0.7025
# Epoch [214/250], Train loss: 0.6974, Val loss: 0.7478, Val acc: 0.6871
# Epoch [215/250], Train loss: 0.7051, Val loss: 0.7630, Val acc: 0.6929
# Epoch [216/250], Train loss: 0.7115, Val loss: 0.7486, Val acc: 0.6718
# Epoch [217/250], Train loss: 0.8050, Val loss: 0.7467, Val acc: 0.6622
# Epoch [218/250], Train loss: 0.7640, Val loss: 0.7575, Val acc: 0.6679
# Epoch [219/250], Train loss: 0.8485, Val loss: 0.7606, Val acc: 0.6449
# Epoch [220/250], Train loss: 0.7298, Val loss: 0.7581, Val acc: 0.6948
# Epoch [221/250], Train loss: 0.7082, Val loss: 0.7430, Val acc: 0.6910
# Epoch [222/250], Train loss: 0.8074, Val loss: 0.7599, Val acc: 0.6622
# Epoch [223/250], Train loss: 0.8178, Val loss: 0.7506, Val acc: 0.6775
# Epoch [224/250], Train loss: 0.7154, Val loss: 0.7458, Val acc: 0.6929
# Epoch [225/250], Train loss: 0.6091, Val loss: 0.7381, Val acc: 0.6795
# Epoch [226/250], Train loss: 0.7431, Val loss: 0.7502, Val acc: 0.6679
# Epoch [227/250], Train loss: 0.7730, Val loss: 0.7479, Val acc: 0.6699
# Epoch [228/250], Train loss: 0.7120, Val loss: 0.7473, Val acc: 0.6871
# Epoch [229/250], Train loss: 0.5605, Val loss: 0.7384, Val acc: 0.6641
# Epoch [230/250], Train loss: 0.6905, Val loss: 0.7480, Val acc: 0.6718
# Epoch [231/250], Train loss: 0.7085, Val loss: 0.7609, Val acc: 0.6795
# Epoch [232/250], Train loss: 0.7106, Val loss: 0.7542, Val acc: 0.6430
# Epoch [233/250], Train loss: 0.5571, Val loss: 0.7440, Val acc: 0.6795
# Epoch [234/250], Train loss: 0.7348, Val loss: 0.7537, Val acc: 0.6833
# Epoch [235/250], Train loss: 0.7837, Val loss: 0.7588, Val acc: 0.7006
# Epoch [236/250], Train loss: 0.7281, Val loss: 0.7443, Val acc: 0.6795
# Epoch [237/250], Train loss: 0.8408, Val loss: 0.7519, Val acc: 0.6795
# Epoch [238/250], Train loss: 0.7900, Val loss: 0.7362, Val acc: 0.7025
# Epoch [239/250], Train loss: 0.8291, Val loss: 0.7629, Val acc: 0.6910
# Epoch [240/250], Train loss: 0.7647, Val loss: 0.7366, Val acc: 0.6910
# Epoch [241/250], Train loss: 0.7612, Val loss: 0.7560, Val acc: 0.7006
# Epoch [242/250], Train loss: 0.7535, Val loss: 0.7336, Val acc: 0.7083
# Epoch [243/250], Train loss: 0.7843, Val loss: 0.7338, Val acc: 0.7121
# Epoch [244/250], Train loss: 0.5257, Val loss: 0.7444, Val acc: 0.7006
# Epoch [245/250], Train loss: 0.7795, Val loss: 0.7393, Val acc: 0.7006
# Epoch [246/250], Train loss: 0.7516, Val loss: 0.7339, Val acc: 0.7063
# Epoch [247/250], Train loss: 0.8000, Val loss: 0.7551, Val acc: 0.6603
# Epoch [248/250], Train loss: 0.7974, Val loss: 0.7593, Val acc: 0.6756
# Epoch [249/250], Train loss: 0.7399, Val loss: 0.7345, Val acc: 0.6987
# Epoch [250/250], Train loss: 0.7078, Val loss: 0.7437, Val acc: 0.6852

# %%
assert isinstance(large_model, nn.Module), "large_model should be a torch.nn.Module"
test_model_output_shape(large_model)

# %% [markdown]
# Again, draw the decision regions of the network. What do you expect to see now? How will the regions differ from the previous ones?

# %%
plot_decision_region(
    large_model,
    dataset_train.x,
    dataset_train.y,
    dataset_val.x,
    dataset_val.y,
)

# %% [markdown]
# How do the decision regions differ between the tiny, large and the network you trained? Can you explain why this happens? Relate your answer to the concepts you learned in the first lectures.

# %% [markdown]
# **Your answer:** The tiny model has simple linear regions, while the main model and especially the large model can create more flexible and non-linear boundaries around the observed clusters. This happens because models with more hidden units and layers have higher capacity and can represent more complex functions. Higher capacity can improve training accuracy, but it can also overfit isolated observations, so validation performance is needed to assess generalization.

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# Back to your original model. Once you achieved at least 60% accuracy in the validation set with your main model, we are done with its training. Now we'll evaluate the performance of your classifier on the test set.

# %% [markdown]
# Compute the accuracy on the test set.

# %%
model.eval()
n_correct = 0
n_samples = 0

with torch.no_grad():
    for batch_x, batch_y in loader_test:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        predictions = model(batch_x).argmax(dim=1)
        n_correct += (predictions == batch_y).sum().item()
        n_samples += batch_y.size(0)

main_model_test_accuracy = n_correct / n_samples
print(f"Test accuracy: {main_model_test_accuracy:.3f}.")
# Out:
# Test accuracy: 0.657.

# %%
assert main_model_test_accuracy > 0.6

# %% [markdown]
# Most likely, you'll get a different (slightly worse) accuracy than the one you got on the validation set. Why is this? Also, why do we need both a test and validation set?

# %% [markdown]
# **Your answer:** Validation accuracy can differ from test accuracy because the validation and test sets contain different random samples. The validation set is used repeatedly to select the model architecture and hyperparameters, so it can become slightly optimistic. The test set is kept separate until the end to provide an unbiased estimate of how well the final model generalizes to new sightings.

# %% [markdown]
# Next, compute the confusion matrix of your predictions on the test set and save it as `conf_mat`.

# %%
from sklearn.metrics import confusion_matrix

model.eval()
all_predictions = []
all_labels = []

with torch.no_grad():
    for batch_x, batch_y in loader_test:
        batch_x = batch_x.to(device)
        predictions = model(batch_x).argmax(dim=1).cpu()
        all_predictions.append(predictions)
        all_labels.append(batch_y.cpu())

test_predictions = torch.cat(all_predictions).numpy()
test_labels = torch.cat(all_labels).numpy()
conf_mat = confusion_matrix(test_labels, test_predictions, labels=[0, 1, 2])
print(conf_mat)
# Out:
# [[ 79  22  44]
#  [ 13  86  39]
#  [ 25   0 109]]

# %%
assert isinstance(conf_mat, np.ndarray) or isinstance(
    conf_mat, torch.Tensor
), "conf_mat should be a numpy array or torch.Tensor"
assert conf_mat.shape == (3, 3), "conf_mat should have shape (3, 3), i.e. 3 classes"
assert np.sum(conf_mat) == len(
    dataset_test
), "conf_mat should sum up to the number of test samples"
_tmp_test_accuracy = (
    main_model_test_accuracy.cpu().detach().numpy()
    if isinstance(main_model_test_accuracy, torch.Tensor)
    else main_model_test_accuracy
)
assert np.abs(np.sum(np.diag(conf_mat)) / np.sum(conf_mat) - _tmp_test_accuracy) < 0.01

# %% [markdown]
# What can you conclude from the computed accuracy and confusion matrix?

# %% [markdown]
# **Your answer:** The model obtains an accuracy of about 68%, which is substantially better than the 33% random baseline for three classes. Tauros has the largest number of correct predictions, whereas Diglett and Seel are more often confused with the other classes. This is consistent with the geographical plots: Tauros is more spatially concentrated, while the other classes have more overlapping or scattered sightings.

# %% [markdown]
# ## 6. Exploration

# %% [markdown]
# You have now trained and evaluated a neural network for this particular classification task. Can you provide a brief explanation as to how you could use it to decide where to travel, if you're interested in capturing the aforementioned Pokemons?

# %% [markdown]
# **Your answer:** I could evaluate a grid of candidate locations with the trained model and inspect the predicted class probabilities. For a Pokémon I want to catch, I would choose a destination or region where its predicted probability is highest, then use the model as one input when planning the trip. The recommendation should be treated cautiously because it is based on historical sightings and only uses the features supplied to the model.

# %% [markdown]
# Is (are) there any other feature(s) from the original dataset (e.g. hour of the day, pressure, wind speed, population density, etc.) which you think would be valuable to add as an input feature to your classifier to improve its performance?

# %% [markdown]
# **Your answer:** Temperature and pressure could be useful additional features. Pokémon sightings may be associated with weather conditions, and these variables may help distinguish species that occur in similar geographical areas. They should be evaluated on a validation set, since a relationship in this dataset does not necessarily imply a causal effect.

# %% [markdown]
# To investigate your hypothesis, plot a histogram of the selected feature(s) for each one of the pokemons we're interested in. For example, if you think pressure and population density are valuable for prediction, plot 6 histograms. 3 of them will be the pressure histograms for each class ('Diglett', 'Seel' and 'Tauros'), and the other 3 will be the population density for each class.

# %%
# Reload only the selected original features; the earlier dataframe intentionally
# retained only latitude, longitude, class, and name.
selected_features = ["temperature", "pressure"]
exploration_df = pd.read_csv(
    "./archive/300k.csv",
    usecols=["class", *selected_features],
    low_memory=False,
)
exploration_df["name"] = exploration_df["class"].map(name_dict)
exploration_df = exploration_df[
    exploration_df["name"].isin(["Diglett", "Seel", "Tauros"])
]

pokemon_names = ["Diglett", "Seel", "Tauros"]
fig, axes = plt.subplots(
    len(selected_features), len(pokemon_names), figsize=(15, 7)
)

for row, feature in enumerate(selected_features):
    for col, pokemon in enumerate(pokemon_names):
        values = exploration_df.loc[
            exploration_df["name"] == pokemon, feature
        ].dropna()
        axes[row, col].hist(values, bins=25, color=f"C{col}", alpha=0.8)
        axes[row, col].set_title(f"{pokemon}: {feature}")
        axes[row, col].set_xlabel(feature)
        axes[row, col].set_ylabel("Number of sightings")

fig.suptitle("Weather-feature distributions by Pokémon", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# What does/do this/these histogram(s) show you? Could it be beneficial to add this/these new feature(s) as input? Explain why/why not.

# %% [markdown]
# **Your answer:** The histograms show that Seel sightings tend to occur at lower temperatures and at slightly higher pressures than Diglett and Tauros. Diglett and Tauros still overlap substantially, so these features will not perfectly separate all classes. Adding temperature and pressure could nevertheless improve classification, particularly when location alone is ambiguous; the resulting performance should be checked on the validation and test sets.

# %% [markdown]
# The purpose was this assignment was mostly to make you design a network for classification, using this Pokemon dataset as a use case. However, if you want to find those three particular Pokemons, most likely using a network for classification is not the best approach. An alternative would be to perform localization by using regression instead. How could we formulate this as a regression problem? **Can you state some pros and cons of approach this as a regression problem instead of a classification problem?** (We do not expect very detailed answers, the goal is to think about the pros and cons with these two different ways of formulating the problem.)

# %% [markdown]
# **Your answer:** A regression formulation could use weather and time features, together with the desired Pokémon species, as inputs and predict a latitude-longitude pair as the target. A benefit is that it gives a continuous recommended location rather than only a class label at a preselected location. However, sightings for one Pokémon can occur in several distant regions, making the target multi-modal; a standard regression model may predict an unhelpful average location. It would also require an appropriate geographic distance loss. For this dataset, classification is more natural for answering which Pokémon is likely to appear at a given location.

# %% [markdown]
# ## 7. (optional)

# %% [markdown]
# Assuming you found useful new features in the last part of this assignment, train a new classifier that uses these featues as well. Did the accuracy on the validation set improve? What's the highest accuracy you can achieve?

# %%
# YOUR CODE HERE
